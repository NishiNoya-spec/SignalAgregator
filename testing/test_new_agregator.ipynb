# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### dto

# %%
from dataclasses import dataclass
from datetime import datetime
from typing import Dict, List, Optional


@dataclass
class Segment:
    start_point: float
    end_point: float
    target_segments: List[str]


@dataclass
class SourceSettings:
    source: str
    type: str
    handler: str
    rolling_number: str
    encoding: str
    is_single: bool
    main_folder: str
    key_folder: str
    nested_folders: str
    filename_key: str
    interpolation_type: str
    interpolation: Optional[float]
    segments: Dict[str, Segment]
    forbidden_columns: List[str]
    filtration_methods: List[str]
    secondary_features: List[str]
    aggregation_methods: List[str]
    billet_column: str
    convert_columns: Dict[str, str]


@dataclass
class PipelineSetup:
    MIN_TIME: datetime    # ограничение файлов по минимальной дате
    MAX_TIME: datetime    # ограничение файлов по максимальной дате
    NUM_OF_CORES: int    # количество выделенных ядер ЦПУ
    MARK_FILTER: bool    # фильтровать или нет марки рельс
    MARK: List[str]    # марка рельса
    PATH_TO_MATERIALS: Optional[str]    # путь до вспомогательных материалов
    PATH_TO_METADATA: str    # пути до данных
    PATH_TO_RESULT: str    # путь до папки с результатом. Создавать самим
    METADATA_BILLET_ID: str    # имя столбца с ИД заготовки


@dataclass
class Materials:
    PATHS: dict


@dataclass
class CutPoint:
    L_DELTA_MIN: float
    L_DELTA_MAX: float
    L_WIN: int
    R_DELTA_MIN: float
    R_DELTA_MAX: float
    R_WIN: int

# %%
import ast

def parse_settings(settings: pd.DataFrame) -> Dict[str, SourceSettings]:
    sources = {}
    for _, source_settings in settings.iteritems():
        source_settings = source_settings.fillna("")

        # Парсим сегменты
        segments = {}
        for segment_data in str(source_settings["segments"]).split("\n"):
            segment_id, start, end, target_ids = eval(segment_data)
            segments[f"{source_settings['source']}_{segment_id}"] = Segment(
                start_point=start, end_point=end, target_segments=target_ids
            )
        # Парсим специальные колонки
        convert_columns = {}
        if source_settings["convert_columns"] != '':
            for convert_col in str(source_settings["convert_columns"]
                                   ).split("\n"):
                colname, convert_type = eval(convert_col)
                convert_columns[colname] = convert_type

        # Парсим остальные настройки источника
        if source_settings['interpolation_type'] == 'by value':
            interp = float(source_settings['interpolation'])
        elif source_settings['interpolation_type'] == 'by source':
            interp = source_settings['interpolation']
        elif source_settings['interpolation_type'] == "":
            interp = None
        else:
            raise NameError(
                f"Unknown interpolation type for source "
                f"{source_settings['source']}"
            )

        sources[source_settings['source']] = SourceSettings(
            source=source_settings['source'],
            type=source_settings['type'],
            handler=source_settings['handler'],
            rolling_number=str(source_settings['rolling_number']),
            encoding=source_settings['encoding'],
            is_single=source_settings['is_single'],
            main_folder=source_settings['main_folder'],
            key_folder=source_settings['key_folder'],
            nested_folders=source_settings['nested_folders'],
            filename_key=source_settings['filename_key'],
            interpolation_type=source_settings['interpolation_type'],
            billet_column=source_settings['billet_column'],
            interpolation=interp,
            segments=segments,
            forbidden_columns=ast.literal_eval(
                source_settings['forbidden_columns']
            ),
            filtration_methods=ast.literal_eval(
                source_settings['filtration_methods']
            ),
            secondary_features=ast.literal_eval(
                source_settings['secondary_features']
            ),
            aggregation_methods=ast.literal_eval(
                source_settings['agg_methods']
            ),
            convert_columns=convert_columns
        )

    return sources

# %%
settings = pd.read_excel(
    "exploration/agregator/run/settings.xlsx", index_col=[0], header=None
).iloc[:, :-1]
settings
# Out:
#                                                  1  \
# 0
# source                                      LNK100
# rolling_number                                   1
# handler                                       BASE
# type                                        target
# encoding                                     UTF-8
# is_single                                    False
# main_folder              \\ZSMK-9684-001\Data\2023
# key_folder                                  ipsrnk
# nested_folders                   rail_points_files
# filename_key                                   NaN
# interpolation_type                        by value
# interpolation                                  103
# segments                             [1, 0, 3, []]
# billet_column                         BilletPoints
# filtration_methods                         ["std"]
# secondary_features                         ["abs"]
# agg_methods         ['tg', 'max', 'min', 'median']
# forbidden_columns                               []
# convert_columns                                NaN
#
#                                                                     2  \
# 0
# source                                                             U0
# rolling_number                                                      1
# handler                                                          BASE
# type                                                          feature
# encoding                                                        UTF-8
# is_single                                                       False
# main_folder                                 \\ZSMK-9684-001\Data\2023
# key_folder                                                         U0
# nested_folders                                  rollings_points_files
# filename_key                                                      NaN
# interpolation_type                                           by value
# interpolation                                                     103
# segments            [1, 0, 3, ['LNK100_1']]\n[2, 3, 6, ['LNK100_1'...
# billet_column                                           billet_points
# filtration_methods                                            ['std']
# secondary_features                                            ['abs']
# agg_methods                            ['max', 'min','median','mean']
# forbidden_columns                                          ['moment']
# convert_columns                                                   NaN
#
#                                                                     3  \
# 0
# source                                                       WBF_PIRO
# rolling_number                                                      1
# handler                                                       WBFPIRO
# type                                                          feature
# encoding                                                        UTF-8
# is_single                                                       False
# main_folder                                 \\ZSMK-9684-001\Data\2023
# key_folder                                                        wbf
# nested_folders                                 billet_pirometer_files
# filename_key                                                      NaN
# interpolation_type                                                NaN
# interpolation                                                     NaN
# segments                                  [1, 0, "end", ['LNK100_1']]
# billet_column                                                  moment
# filtration_methods                                                 []
# secondary_features                                                 []
# agg_methods                            ['max', 'min','median','mean']
# forbidden_columns   ["BEAM_VERT_ENC", "BEAM_HOR_ENC_POS", "DM_ENC_...
# convert_columns                                                   NaN
#
#                                             4
# 0
# source                                WBF_sgl
# rolling_number                              1
# handler                             WBFSINGLE
# type                                  feature
# encoding                                 ANSI
# is_single                                   1
# main_folder         \\ZSMK-9684-001\Data\2023
# key_folder                                wbf
# nested_folders                            NaN
# filename_key                              NaN
# interpolation_type                        NaN
# interpolation                             NaN
# segments              [1, 0, 0, ['LNK100_1']]
# billet_column                   billet_number
# filtration_methods                         []
# secondary_features                         []
# agg_methods                                []
# forbidden_columns                          []
# convert_columns                           NaN

# %%
settings_parsed = parse_settings(settings)

# %%
display(settings_parsed)
# Out:
# {'LNK100': SourceSettings(source='LNK100', type='target', handler='BASE', rolling_number='1', encoding='UTF-8', is_single=False, main_folder='\\\\ZSMK-9684-001\\Data\\2023', key_folder='ipsrnk', nested_folders='rail_points_files', filename_key='', interpolation_type='by value', interpolation=103.0, segments={'LNK100_1': Segment(start_point=0, end_point=3, target_segments=[])}, forbidden_columns=[], filtration_methods=['std'], secondary_features=['abs'], aggregation_methods=['tg', 'max', 'min', 'median'], billet_column='BilletPoints', convert_columns={}),
#  'U0': SourceSettings(source='U0', type='feature', handler='BASE', rolling_number='1', encoding='UTF-8', is_single=False, main_folder='\\\\ZSMK-9684-001\\Data\\2023', key_folder='U0', nested_folders='rollings_points_files', filename_key='', interpolation_type='by value', interpolation=103.0, segments={'U0_1': Segment(start_point=0, end_point=3, target_segments=['LNK100_1']), 'U0_2': Segment(start_point=3, end_point=6, target_segments=['LNK100_1']), 'U0_3': Segment(start_point=30, end_point=70, target_segments=['LNK100_1']), 'U0_4': Segment(start_point=-3, end_point='end', target_segments=['LNK100_1']), 'U0_5': Segment(start_point=-6, end_point=-3, target_segments=['LNK100_1'])}, forbidden_columns=['moment'], filtration_methods=['std'], secondary_features=['abs'], aggregation_methods=['max', 'min', 'median', 'mean'], billet_column='billet_points', convert_columns={}),
#  'WBF_PIRO': SourceSettings(source='WBF_PIRO', type='feature', handler='WBFPIRO', rolling_number='1', encoding='UTF-8', is_single=False, main_folder='\\\\ZSMK-9684-001\\Data\\2023', key_folder='wbf', nested_folders='billet_pirometer_files', filename_key='', interpolation_type='', interpolation=None, segments={'WBF_PIRO_1': Segment(start_point=0, end_point='end', target_segments=['LNK100_1'])}, forbidden_columns=['BEAM_VERT_ENC', 'BEAM_HOR_ENC_POS', 'DM_ENC_HOR_POS', 'DML_VERT_POS', 'DMR_VERT_POS'], filtration_methods=[], secondary_features=[], aggregation_methods=['max', 'min', 'median', 'mean'], billet_column='moment', convert_columns={}),
#  'WBF_sgl': SourceSettings(source='WBF_sgl', type='feature', handler='WBFSINGLE', rolling_number='1', encoding='ANSI', is_single=1, main_folder='\\\\ZSMK-9684-001\\Data\\2023', key_folder='wbf', nested_folders='', filename_key='', interpolation_type='', interpolation=None, segments={'WBF_sgl_1': Segment(start_point=0, end_point=0, target_segments=['LNK100_1'])}, forbidden_columns=[], filtration_methods=[], secondary_features=[], aggregation_methods=[], billet_column='billet_number', convert_columns={})}

# %% [markdown]
# ### Transcription Class

# %%
from copy import copy
from typing import Dict, List

class Transcription:

    def __init__(
        self,
        workcenter: str = "",
        workunit: str = "",
        rolling_number: str = "",
        name: str = "",
        model: str = "",
        interpolation: str = "",
        sector_range: str = "",
        preprocessing: str = "",
        aggregation: str = "",
        secondary_functions: str = ""
    ):
        self.workcenter = workcenter
        self.workunit = workunit
        self.rolling_number = rolling_number
        self.name = name
        self.model = model
        self.interpolation = interpolation
        self.sector_range = sector_range
        self.preprocessing = preprocessing
        self.aggregation = aggregation
        self.secondary_functions = secondary_functions

    def __repr__(self):
        return str(self)

    def __hash__(self):
        return hash(str(self))

    def __eq__(self, other):
        return str(self) == str(other)

    def __str__(self):
        return (
            f"{self._add_under(self.workcenter)}"
            f"{self._add_under(self.workunit)}"
            f"{self._add_under(self.rolling_number)}"
            f"{self._add_under(self.name)}"
            f"{self._add_under(self.model)}"
            f"{self._add_under(self.interpolation)}"
            f"{self._add_under(self.sector_range)}"
            f"{self._add_dot(self.preprocessing)}"
            f"{self._add_under(self.aggregation)}"
        )[:-1]

    def add_tags(self, tags: Dict[str, List[str]], replace: bool = False):
        new_transcription = copy(self)
        for tag_type, tags_values in tags.items():
            if replace:
                full_tag = tags_values[0]
                for tag in tags_values[1:]:
                    full_tag += new_transcription._add_under(tag)
                setattr(new_transcription, tag_type, full_tag)
            else:

                for tag in tags_values:
                    transcription_attr = getattr(new_transcription, tag_type)
                    setattr(
                        new_transcription,
                        tag_type,
                        f"{new_transcription._add_under(transcription_attr)}"
                        f"{tag}",
                    )
        return new_transcription

    @staticmethod
    def _add_under(string: str):
        return f"{string}_" if string != "" else ""

    @staticmethod
    def _add_dot(string: str):
        return f"{string}." if string != "" else ""

# %%
### Пример инициализации объекта класса `Transcription`:
transcription = Transcription(
    workcenter="mill",
    workunit="bd1",
    rolling_number="1",
    name="temp",
    model="l1",
    interpolation="i103.0",
    sector_range="h0.0-3.0",
    preprocessing="ni",
    aggregation="min",
    secondary_functions=""
)

print(transcription)
# Out:
# mill_bd1_1_temp_l1_i103.0_h0.0-3.0_ni.min

# %%
### Метод `__repr__` 

transcription.__repr__()
# Out:
# 'mill_bd1_1_temp_l1_i103.0_h0.0-3.0_ni.min'

# %%
### Метод `__hash__`

transcription.__hash__()
# Out:
# 7894055372663120742

# %%
### Метод `__str__`

transcription.__str__()
# Out:
# 'mill_bd1_1_temp_l1_i103.0_h0.0-3.0_ni.min'

# %%
### Метод `add_tags`

new_transcription = transcription.add_tags(
    {
    "sector_range": ["t0.0-3.0"],
    "aggregation": ["max"]
}, replace=True)
print(new_transcription)
# Out:
# mill_bd1_1_temp_l1_i103.0_t0.0-3.0_ni.max

# %% [markdown]
# ### Array Class

# %%
from copy import copy
from typing import Dict, List

class Array:

    def __init__(
        self,
        transcription: Transcription,
        values: np.array,
        is_numeric: bool,
        is_billet: bool,
    ):
        self.transcription = transcription
        self.is_numeric = is_numeric
        self.is_billet = is_billet
        self.values = values
        self.key = str(self.transcription)

    def __repr__(self):
        return (
            f"{str(self.transcription)}; "
            f"is_numeric={self.is_numeric}"
            f", is_billet={self.is_billet}"
        )

    def replace_values(self, new_values: np.array):
        self.values = new_values

    def append_keys_to_transcription(
        self, tags: Dict[str, List[str]], replace: bool = False
    ):
        new_transcription = self.transcription.add_tags(tags, replace)
        new_array = copy(self)
        new_array.transcription = new_transcription
        new_array.key = str(new_transcription)
        return new_array

# %%
transcription = Transcription(
    workcenter="mill",
    workunit="bd1",
    rolling_number="1",
    name="temp",
    model="l1",
    interpolation="i103.0",
    sector_range="h0.0-3.0",
    preprocessing="ni",
    aggregation="min",
    secondary_functions=""
)

values = np.array([559.94, 572.96, 582.03, 594.40, 606.77, 620.23, 620.23, 640.36, 1023.74, 1062.85])

array = Array(
    transcription=transcription,
    values=values,
    is_numeric=True,  # Предположим, что все значения являются числами
    is_billet=False   # Предположим, что это не заготовка
)

print(array)
# Out:
# mill_bd1_1_temp_l1_i103.0_h0.0-3.0_ni.min; is_numeric=True, is_billet=False

# %%
# Применяем метод append_keys_to_transcription
tags = {"aggregation": ["max"]}
new_array = array.append_keys_to_transcription(tags, replace=False)

print(new_array.key)
# Out:
# mill_bd1_1_temp_l1_i103.0_h0.0-3.0_ni.min_max

# %% [markdown]
# ### FeaturesGenerator Class

# %%
from copy import copy

class FeaturesGenerator:

    def __init__(self):
        self.methods = {
            "abs": self.absolute,
            "norm": self.norm,
        }

    def get_method_values(self, method, *args, **kwargs):
        return self.methods[method](*args, **kwargs)

    @staticmethod
    def absolute(data_array: Array, *args, **kwargs) -> Array:
        """Модуль"""
        transcription = copy(data_array.transcription)
        transcription.add_tags({"preprocessing": ["abs"]}, )
        array = Array(
            transcription=transcription,
            values=abs(data_array.values),
            is_numeric=True,
            is_billet=False
        )
        return array

    @staticmethod
    def norm(data_array: Array, MIN, MAX, *args, **kwargs) -> Array:
        """Модуль"""
        transcription = copy(data_array.transcription)
        name = (
            data_array.transcription.workunit + "_"
            + data_array.transcription.name
        )
        transcription.add_tags({"preprocessing": ["norm"]})
        array = Array(
            transcription=transcription,
            values=np.array(
                [
                    (val - MIN[name]) / (MAX[name] - MIN[name])
                    for val in data_array.values
                ]
            ),
            is_numeric=True,
            is_billet=False
        )
        return array

# %%
# Создаем объект FeaturesGenerator
features_generator = FeaturesGenerator()

# Создаем массив данных
values = np.array([-559.94, 572.96, -582.03, 594.40, -606.77, 620.23, -640.36, 1023.74, -1062.85])
array = Array(
    transcription=transcription,
    values=values,
    is_numeric=True,
    is_billet=False
)

# Применяем метод absolute
result_array = features_generator.absolute(array)

result_array.values
# Out:
# array([ 559.94,  572.96,  582.03,  594.4 ,  606.77,  620.23,  640.36,
#        1023.74, 1062.85])

# %%
# Создаем объект FeaturesGenerator
features_generator = FeaturesGenerator()

# Создаем массив данных
values = np.array([-559.94, 572.96, -582.03, 594.40, -606.77, 620.23, -640.36, 1023.74, -1062.85])
array = Array(
    transcription=transcription,
    values=values,
    is_numeric=True,
    is_billet=False
)

# Задаем значения MIN и MAX
MIN = {"bd1_temp": -1062.85}
MAX = {"bd1_temp": 1023.74}

# Применяем метод norm
result_array = features_generator.norm(array, MIN, MAX)

result_array.values
# Out:
# array([0.24102004, 0.78396331, 0.23043339, 0.79423845, 0.21857672,
#        0.8066175 , 0.20247869, 1.        , 0.        ])

# %% [markdown]
# ### SourceSettings Class

# %%
from exploration.agregator import constants
from exploration.agregator.dto import SourceSettings

class SourceDataset:    

    def __init__(self, settings: SourceSettings):
        self.settings = settings
        self.data = {}
        self.billet_key = str(
            Transcription(
                workunit=self.settings.source,
                rolling_number=self.settings.rolling_number,
                name=self.settings.billet_column,
                interpolation="ni"
            )
        )

    def __iter__(self):
        self._data_keys = list(self.data.keys())
        self._index = -1
        return self

    def __next__(self):
        if len(self._data_keys) != len(list(self.data.keys())):
            raise RuntimeError("object changed size during iterations")
        if self._index < len(self.data) - 1:
            self._index += 1
            return self.data[self._data_keys[self._index]]
        else:
            raise StopIteration

    def __getitem__(self, key: str):
        return self.data[key]

    def __repr__(self):
        return f"{self.settings.source}; " \
                f"billet='{self.settings.billet_column}'"

    def billet_array(self):
        """Возвращает Array, для которого is_billet = True"""
        return self.data[self.billet_key]

    def append_dataframe_to_source_data(self, data: pd.DataFrame):
        """Формирует из DataFrame набор данных в формате Dict[Array]"""
        for name, values in data.iteritems():
            values = values.to_numpy()
            is_numeric = self._is_numeric(values)
            transcription = Transcription(
                workunit=self.settings.source,
                rolling_number=self.settings.rolling_number,
                name=str(name),
                interpolation="ni"
            )
            is_billet = (
                True if str(transcription) == self.billet_key else False
            )
            array = Array(
                transcription=transcription,
                values=values,
                is_numeric=is_numeric,
                is_billet=is_billet
            )
            self.data[str(transcription)] = array

    def append_array_to_source_data(self, array: Array, old_key: str = None):
        """Добавляет новый Array"""
        self.data[array.key] = array
        if old_key == self.billet_key:
            self.billet_key = str(array.transcription)

    def replace_array_values(self, key: str, new_values: np.array):
        """Изменяет значения определнного Array"""
        self.data[key].replace_values(new_values)

    def remove_arrays(self, arrays: List[str]):
        for key in arrays:
            self.data.pop(key)

    def append_tags_to_array(
        self, key: str, tags: Dict[str, List[str]], replace: bool = False
    ):
        new_array = self.data[key].append_keys_to_transcription(tags, replace)
        self.remove_arrays([key])
        self.append_array_to_source_data(new_array, key)

    def append_tags_to_all_arrays(
        self, tags: Dict[str, List[str]], replace: bool = False
    ):
        init_keys = self.data.keys()
        for key in init_keys:
            new_array = self.data[key].append_keys_to_transcription(
                tags, replace
            )
            self.remove_arrays([key])
            self.append_array_to_source_data(new_array, key)

    def return_arrays_by_tags(self, tags: Dict[str, str]) -> List[Array]:
        arrays = []
        for array in self:
            for tag_key, tag_value in tags.items():
                if getattr(array.transcription, tag_key) != tag_value:
                    break
                arrays.append(array)
        return arrays

    @staticmethod
    def _is_numeric(values: np.array) -> bool:
        column_type = values.dtype
        is_numeric = False
        for parent_type in constants.AVAILABLE_TYPES:
            if np.issubdtype(column_type, parent_type):
                is_numeric = True
                break
        return is_numeric

# %%
# Создание объекта SourceSettings
settings = SourceSettings(
    source="LNK100",
    type="feature",
    handler="BASE",
    rolling_number="",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[]),
            "LNK100_2": Segment(start_point=3, end_point=6, target_segments=["LNK100_1"]),
            "LNK100_3": Segment(start_point=30, end_point=70, target_segments=["LNK100_1"]),
            "LNK100_4": Segment(start_point=-3, end_point="end", target_segments=["LNK100_1"]),
            "LNK100_5": Segment(start_point=-6, end_point=-3, target_segments=["LNK100_1"])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['tg', 'max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)
# Создание объекта SourceDataset
dataset = SourceDataset(settings)

# %%
iter(dataset)
# Out:
# LNK100; billet='BilletPoints'

# %%
repr(dataset)
# Out:
# "LNK100; billet='BilletPoints'"

# %%
df = pd.DataFrame({
    'BilletPoints': [0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25, 0.275, 0.3, 0.325, 0.35, 0.375, 0.4, 0.425, 0.45, 0.475, 0.5, 0.525, 0.55, 0.575, 0.6, 0.625, 0.65, 0.675, 0.7, 0.725, 0.75, 0.775, 0.8, 0.825, 0.85, 0.875, 0.9, 0.925, 0.95, 0.975, 1],
    'Vert1000': [133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 134, 134, 134, 134, 134, 133, 132, 131, 130, 130, 129, 129, 129, 129, 127, 126, 125, 126, 124],
    'Vert1500': [224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 224, 225, 226, 226, 225, 224, 223, 220, 218, 215, 213, 209, 205, 203, 200, 199, 197, 195, 194, 191],
    'Vert2000': [312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 312, 311, 310, 309, 306, 308, 305, 301, 297, 292, 289, 284, 278, 277, 275, 273, 271, 270, 268, 264],
    'Vert3000': [400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 392, 383, 375, 367, 360, 353, 342, 332, 321, 314, 305, 298, 292, 285, 282, 277, 273, 268, 264],
    'Hor1000': [318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 318, 317, 322, 329, 327, 338, 349, 358, 368, 377, 386, 393, 398, 407, 411, 410, 412, 414, 419, 422],
    'Hor1500': [747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 747, 752, 759, 755, 761, 763, 766, 767, 768, 768, 767, 766, 762, 758, 751, 742, 735, 726, 720, 716],
    'Hor2000': [1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1152, 1133, 1125, 1108, 1096, 1078, 1062, 1046, 1031, 1018, 1000, 981, 965, 944, 932, 912, 889, 871, 854],
    'Torsion': [-698, -698, -698, -698, -698, -694, -670, -658, -641, -635, -631, -609, -589, -558, -524, -483, -443, -398, -361, -336, -287, -248, -222, -200, -184, -177, -181, -185, -184, -183, -183, -177, -166, -157, -141, -120, -88, -51, -12, 30]
})

# %%
dataset.append_dataframe_to_source_data(df)

# %%
display(dataset.data)
# Out:
# {'LNK100_BilletPoints_ni': LNK100_BilletPoints_ni; is_numeric=True, is_billet=True,
#  'LNK100_Vert1000_ni': LNK100_Vert1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert1500_ni': LNK100_Vert1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert2000_ni': LNK100_Vert2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert3000_ni': LNK100_Vert3000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1000_ni': LNK100_Hor1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1500_ni': LNK100_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor2000_ni': LNK100_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Torsion_ni': LNK100_Torsion_ni; is_numeric=True, is_billet=False}

# %%
dataset.billet_key
# Out:
# 'LNK100_BilletPoints_ni'

# %%
dataset.data["LNK100_Vert1000_ni"].values
# Out:
# array([133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133,
#        133, 133, 133, 133, 133, 133, 133, 133, 134, 134, 134, 134, 134,
#        133, 132, 131, 130, 130, 129, 129, 129, 129, 127, 126, 125, 126,
#        124], dtype=int64)

# %%
dataset.data["LNK100_Vert1000_ni"].transcription
# Out:
# LNK100_Vert1000_ni

# %%
# Создаем словарь тегов для добавления
tags = {
    "interpolation": ["i103.0"]
}

# Вызываем метод append_tags_to_array, передавая ключ массива и словарь тегов
dataset.append_tags_to_array("LNK100_Vert1000_ni", tags, replace=True)

# %%
dataset.data
# Out:
# {'LNK100_BilletPoints_ni': LNK100_BilletPoints_ni; is_numeric=True, is_billet=True,
#  'LNK100_Vert1500_ni': LNK100_Vert1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert2000_ni': LNK100_Vert2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert3000_ni': LNK100_Vert3000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1000_ni': LNK100_Hor1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1500_ni': LNK100_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor2000_ni': LNK100_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Torsion_ni': LNK100_Torsion_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert1000_i103.0': LNK100_Vert1000_i103.0; is_numeric=True, is_billet=False}

# %%
dataset.data
# Out:
# {'LNK100_BilletPoints_ni': LNK100_BilletPoints_ni; is_numeric=True, is_billet=True,
#  'LNK100_Vert1500_ni': LNK100_Vert1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert2000_ni': LNK100_Vert2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert3000_ni': LNK100_Vert3000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1000_ni': LNK100_Hor1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1500_ni': LNK100_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor2000_ni': LNK100_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Torsion_ni': LNK100_Torsion_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert1000_i103.0': LNK100_Vert1000_i103.0; is_numeric=True, is_billet=False}

# %%
# Cловарь с тегами, которые хотим проверить
tags_to_check = {
    "interpolation": "i103.0",
}

# Получаем список массивов, удовлетворяющих заданным тегам
arrays_with_tags = dataset.return_arrays_by_tags(tags_to_check)

# Выводим результат
for array in arrays_with_tags:
    print(array)
# Out:
# LNK100_Vert1000_i103.0; is_numeric=True, is_billet=False

# %%
arrays_with_tags[0].transcription
# Out:
# LNK100_Vert1000_i103.0

# %%
dataset.data[arrays_with_tags[0].transcription].values
# Out:
# array([133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133, 133,
#        133, 133, 133, 133, 133, 133, 133, 133, 134, 134, 134, 134, 134,
#        133, 132, 131, 130, 130, 129, 129, 129, 129, 127, 126, 125, 126,
#        124], dtype=int64)

# %% [markdown]
# ### SecondaryFunctions Class

# %%
class SecondaryFunctions:

    def __init__(self):
        pass

    @staticmethod
    def sort_dataset_ascending_by_billet(
        source_data: SourceDataset
    ) -> SourceDataset:
        """Сортировка billet points по возрастанию"""
        new_sequence = sorted(
            enumerate(source_data.billet_array().values), key=lambda x: x[1]
        )
        new_sequence = [val[0] for val in new_sequence]
        for data_array in source_data:
            new_values = [data_array.values[index] for index in new_sequence]
            source_data.append_tags_to_array(
                data_array.key, {"secondary_functions": ["sortas"]}
            )
            source_data.replace_array_values(
                data_array.key, np.array(new_values)
            )
        return source_data

    @staticmethod
    def approximate_billet_by_bounds(
        source_data: SourceDataset
    ) -> SourceDataset:
        """Аппроксимация столбца Billet к
        необходимой, строго фиксированной размерности"""
        ub = source_data.settings.interpolation
        lb = 0
        max_billet = max(source_data.billet_array().values)
        new_billet_values = (
            source_data.billet_array().values * (ub - lb) / max_billet
        ) + lb
        source_data.replace_array_values(
            source_data.billet_key, new_billet_values
        )
        source_data.append_tags_to_all_arrays(
            {"interpolation": [f"[i_{lb:.1f}_{ub:.1f}]"]}, replace=True
        )
        return source_data

    @staticmethod
    def append_workcenter_to_transcription(
        source_data: SourceDataset, workcenters: Dict[str, str]
    ) -> SourceDataset:
        for data_array in source_data:
            tags = workcenters[data_array.transcription.workunit]
            source_data.append_tags_to_array(
                data_array.key, {"workcenter": [tags]}, replace=True
            )
        return source_data

    @staticmethod
    def cut_wbf_pirometer_signals(
        source_data: SourceDataset, piro_settings: Dict[str, Dict[str, str]]
    ):
        all_target_segments = list(
            set(
                [
                    target for seg in source_data.settings.segments.values()
                    for target in seg.target_segments
                ]
            )
        )
        all_cut_indexes = []
        for name, points in piro_settings["SETTINGS"].items():
            array = source_data.return_arrays_by_tags({"name": name})[0]

            # Ищем точки разделения
            cut_indexes = []
            point_idx = 0
            col_len = len(array.values)
            for idx in range(col_len):
                point_data = CutPoint(*points[point_idx])
                if (idx - point_data.L_WIN < 0
                        or idx + point_data.R_WIN >= col_len):
                    continue
                l_delta = (
                    array.values[idx] - array.values[idx - point_data.L_WIN]
                )
                r_delta = (
                    array.values[idx + point_data.R_WIN] - array.values[idx]
                )
                if (point_data.L_DELTA_MIN <= l_delta <= point_data.L_DELTA_MAX
                        and (point_data.R_DELTA_MIN <= r_delta <=
                                point_data.R_DELTA_MAX)):
                    cut_indexes.append(idx)
                    if point_idx + 1 < len(points):
                        point_idx += 1
                    else:
                        break
            print(cut_indexes)
            all_cut_indexes.extend(cut_indexes)
            for number, indexes in enumerate(zip(cut_indexes[:-1],
                                                    cut_indexes[1:])):
                source_data.settings.segments[f"{name}_{number}"] = Segment(
                    start_point=source_data.billet_array().values[indexes[0]],
                    end_point=source_data.billet_array().values[indexes[1]],
                    target_segments=all_target_segments
                )
        all_cut_indexes = sorted(all_cut_indexes)
        for number, indexes in enumerate(zip(all_cut_indexes[:-1],
                                                all_cut_indexes[1:])):
            source_data.settings.segments[f"ALL_PTS_{number}"] = Segment(
                start_point=source_data.billet_array().values[indexes[0]],
                end_point=source_data.billet_array().values[indexes[1]],
                target_segments=all_target_segments
            )

        print(all_cut_indexes)

        return source_data

    @staticmethod
    def convert_date_columns_to_numeric(
        source_data: SourceDataset, tags_list: List[Dict[str, str]]
    ) -> SourceDataset:
        for tag in tags_list:
            tag_arrays = source_data.return_arrays_by_tags(tag)
            for array in tag_arrays:
                date_values = [
                    (pd.Timestamp(value) - constants.BASE_TIME).total_seconds()
                    for value in array.values
                ]
                min_data = min(date_values)
                converted_values = [value - min_data for value in date_values]
                source_data.replace_array_values(
                    array.key, np.array(converted_values)
                )
                source_data.append_tags_to_array(
                    array.key, {"secondary_functions": ["converted"]}
                )
        return source_data

# %%
secondary_functions = SecondaryFunctions()

secondary_functions.sort_dataset_ascending_by_billet(dataset)
# Out:
# LNK100; billet='BilletPoints'

# %%
dataset.data["LNK100_BilletPoints_ni"].values
# Out:
# array([0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  , 0.225,
#        0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425, 0.45 ,
#        0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 , 0.675,
#        0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875, 0.9  ,
#        0.925, 0.95 , 0.975, 1.   ])

# %%
dataset.billet_array().values
# Out:
# array([0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  , 0.225,
#        0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425, 0.45 ,
#        0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 , 0.675,
#        0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875, 0.9  ,
#        0.925, 0.95 , 0.975, 1.   ])

# %%
dataset.data
# Out:
# {'LNK100_BilletPoints_ni': LNK100_BilletPoints_ni; is_numeric=True, is_billet=True,
#  'LNK100_Vert1500_ni': LNK100_Vert1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert2000_ni': LNK100_Vert2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert3000_ni': LNK100_Vert3000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1000_ni': LNK100_Hor1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor1500_ni': LNK100_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor2000_ni': LNK100_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Torsion_ni': LNK100_Torsion_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert1000_i103.0': LNK100_Vert1000_i103.0; is_numeric=True, is_billet=False}

# %%
secondary_functions.approximate_billet_by_bounds(dataset)
# Out:
# LNK100; billet='BilletPoints'

# %%
dataset.data
# Out:
# {'LNK100_Hor1500_ni': LNK100_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_Hor2000_ni': LNK100_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_Torsion_ni': LNK100_Torsion_ni; is_numeric=True, is_billet=False,
#  'LNK100_Vert1000_i103.0': LNK100_Vert1000_i103.0; is_numeric=True, is_billet=False,
#  'LNK100_BilletPoints_[i_0.0_103.0]': LNK100_BilletPoints_[i_0.0_103.0]; is_numeric=True, is_billet=True,
#  'LNK100_Vert1500_[i_0.0_103.0]': LNK100_Vert1500_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  'LNK100_Vert2000_[i_0.0_103.0]': LNK100_Vert2000_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  'LNK100_Vert3000_[i_0.0_103.0]': LNK100_Vert3000_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  'LNK100_Hor1000_[i_0.0_103.0]': LNK100_Hor1000_[i_0.0_103.0]; is_numeric=True, is_billet=False}

# %%
tags_to_check = {
"interpolation": "[i_0.0_103.0]",
}

# Получаем список массивов, удовлетворяющих заданным тегам
arrays_with_tags = dataset.return_arrays_by_tags(tags_to_check)
arrays_with_tags
# Out:
# [LNK100_BilletPoints_[i_0.0_103.0]; is_numeric=True, is_billet=True,
#  LNK100_Vert1500_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  LNK100_Vert2000_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  LNK100_Vert3000_[i_0.0_103.0]; is_numeric=True, is_billet=False,
#  LNK100_Hor1000_[i_0.0_103.0]; is_numeric=True, is_billet=False]

# %%
secondary_functions.append_workcenter_to_transcription(dataset, {"LNK100": "mill"})
# Out:
# LNK100; billet='BilletPoints'

# %%
dataset.data["mill_LNK100_Hor1500_ni"].transcription.workcenter
# Out:
# 'mill'

# %%
dataset.settings.segments
# Out:
# {'LNK100_1': Segment(start_point=0, end_point=3, target_segments=[]),
#  'LNK100_2': Segment(start_point=3, end_point=6, target_segments=['LNK100_1']),
#  'LNK100_3': Segment(start_point=30, end_point=70, target_segments=['LNK100_1']),
#  'LNK100_4': Segment(start_point=-3, end_point='end', target_segments=['LNK100_1']),
#  'LNK100_5': Segment(start_point=-6, end_point=-3, target_segments=['LNK100_1'])}

# %% [markdown]
# #### WBF_PIRO_CUTTER

# %%
# Создание объекта SourceSettings
settings = SourceSettings(
    source="WBF_PIRO",
    type="feature",
    handler="WBFPIRO",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="billet_pirometer_files",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_PIRO_1": Segment(start_point=0, end_point="end", target_segments=["LNK100_1"])
        },
    forbidden_columns=["BEAM_VERT_ENC", "BEAM_HOR_ENC_POS", "DM_ENC_HOR_POS", "DML_VERT_POS", "DMR_VERT_POS"],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=['max', 'min','median','mean'],
    billet_column="moment",
    convert_columns={}
)
# Создание объекта SourceDataset
piroset = SourceDataset(settings)

# %%
file_path = 'testing/20240307170148_XX-Л210444041_WBF_1_T2.csv'
df = pd.read_csv(file_path, sep=';')
for col in df.drop("moment", axis=1).columns:
    df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce")
df["moment"] = pd.to_datetime(df["moment"])
df
# Out:
#                       moment    TEMP_PIR3    TEMP_PIR1    TEMP_PIR2  \
# 0    2024-03-07 23:59:24.507  1122.627319  1107.378418  1132.494263
# 1    2024-03-07 23:59:24.557  1122.627319  1107.378418  1132.494263
# 2    2024-03-07 23:59:24.607  1122.627319  1107.378418  1132.494263
# 3    2024-03-07 23:59:24.657  1122.627319  1107.378418  1132.494263
# 4    2024-03-07 23:59:24.707  1122.771973  1107.378418  1132.494263
# ...                      ...          ...          ...          ...
# 2368 2024-03-08 00:01:38.807  1107.320557  1083.940918  1092.361084
# 2369 2024-03-08 00:01:38.857  1107.320557  1083.940918  1092.361084
# 2370 2024-03-08 00:01:38.907  1107.320557  1084.288208  1090.798706
# 2371 2024-03-08 00:01:38.957  1107.320557  1084.288208  1090.798706
# 2372 2024-03-08 00:01:39.007  1107.153931  1084.288208  1090.798706
#
#       BEAM_VERT_ENC  BEAM_HOR_ENC_POS  DM_ENC_HOR_POS  DML_VERT_POS  \
# 0         45.315788          5.919983      115.760651    231.720001
# 1         45.842106          5.919983      115.760651    228.500000
# 2         46.894737          5.919983      115.760651    224.399994
# 3         47.421055          5.919983      115.760651    220.339996
# 4         47.947369          5.919983      115.760651    216.339996
# ...             ...               ...             ...           ...
# 2368     100.578949          6.239990      112.552254    407.559998
# 2369     100.578949          6.239990      111.065437    403.579987
# 2370     100.578949          6.239990      110.070496    398.500000
# 2371     100.578949          6.239990      109.679230    394.359985
# 2372     100.578949          6.239990      109.679230    394.359985
#
#       DMR_VERT_POS
# 0       256.759979
# 1       253.659988
# 2       249.739990
# 3       245.860001
# 4       242.059998
# ...            ...
# 2368    385.239990
# 2369    381.199982
# 2370    376.019989
# 2371    371.899994
# 2372    371.899994
#
# [2373 rows x 9 columns]

# %%
piroset.append_dataframe_to_source_data(df)

# %%
import json

# Указываем путь к файлу JSON
file_path = "exploration/agregator/run/materials/wbf_piro_cutter_settings.json"

# Открываем файл и загружаем его содержимое в переменную
with open(file_path, "r") as file:
    piro_settings = json.load(file)

# %%
new_piroset = SecondaryFunctions().cut_wbf_pirometer_signals(piroset, piro_settings)
# Out:
# [153, 469, 752, 1152, 1706]
# [495, 773, 1172, 1596]
# [1892, 2067]
# [77, 1772, 1816, 2098, 2183, 2326]
# [100, 1772, 1820, 2095, 2186, 2322]
# [77, 100, 153, 469, 495, 752, 773, 1152, 1172, 1596, 1706, 1772, 1772, 1816, 1820, 1892, 2067, 2095, 2098, 2183, 2186, 2322, 2326]

# %%
new_piroset.settings.segments
# Out:
# {'WBF_PIRO_1': Segment(start_point=0, end_point='end', target_segments=['LNK100_1']),
#  'BEAM_VERT_ENC_0': Segment(start_point=numpy.datetime64('2024-03-07T23:59:33.107000000'), end_point=numpy.datetime64('2024-03-07T23:59:53.057000000'), target_segments=['LNK100_1']),
#  'BEAM_VERT_ENC_1': Segment(start_point=numpy.datetime64('2024-03-07T23:59:53.057000000'), end_point=numpy.datetime64('2024-03-08T00:00:08.907000000'), target_segments=['LNK100_1']),
#  'BEAM_VERT_ENC_2': Segment(start_point=numpy.datetime64('2024-03-08T00:00:08.907000000'), end_point=numpy.datetime64('2024-03-08T00:00:30.957000000'), target_segments=['LNK100_1']),
#  'BEAM_VERT_ENC_3': Segment(start_point=numpy.datetime64('2024-03-08T00:00:30.957000000'), end_point=numpy.datetime64('2024-03-08T00:01:04.107000000'), target_segments=['LNK100_1']),
#  'BEAM_HOR_ENC_POS_0': Segment(start_point=numpy.datetime64('2024-03-07T23:59:55.457000000'), end_point=numpy.datetime64('2024-03-08T00:00:10.207000000'), target_segments=['LNK100_1']),
#  'BEAM_HOR_ENC_POS_1': Segment(start_point=numpy.datetime64('2024-03-08T00:00:10.207000000'), end_point=numpy.datetime64('2024-03-08T00:00:32.607000000'), target_segments=['LNK100_1']),
#  'BEAM_HOR_ENC_POS_2': Segment(start_point=numpy.datetime64('2024-03-08T00:00:32.607000000'), end_point=numpy.datetime64('2024-03-08T00:00:54.757000000'), target_segments=['LNK100_1']),
#  'DM_ENC_HOR_POS_0': Segment(start_point=numpy.datetime64('2024-03-08T00:01:14.507000000'), end_point=numpy.datetime64('2024-03-08T00:01:23.407000000'), target_segments=['LNK100_1']),
#  'DML_VERT_POS_0': Segment(start_point=numpy.datetime64('2024-03-07T23:59:28.907000000'), end_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), target_segments=['LNK100_1']),
#  'DML_VERT_POS_1': Segment(start_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), end_point=numpy.datetime64('2024-03-08T00:01:09.907000000'), target_segments=['LNK100_1']),
#  'DML_VERT_POS_2': Segment(start_point=numpy.datetime64('2024-03-08T00:01:09.907000000'), end_point=numpy.datetime64('2024-03-08T00:01:25.057000000'), target_segments=['LNK100_1']),
#  'DML_VERT_POS_3': Segment(start_point=numpy.datetime64('2024-03-08T00:01:25.057000000'), end_point=numpy.datetime64('2024-03-08T00:01:29.307000000'), target_segments=['LNK100_1']),
#  'DML_VERT_POS_4': Segment(start_point=numpy.datetime64('2024-03-08T00:01:29.307000000'), end_point=numpy.datetime64('2024-03-08T00:01:36.707000000'), target_segments=['LNK100_1']),
#  'DMR_VERT_POS_0': Segment(start_point=numpy.datetime64('2024-03-07T23:59:30.057000000'), end_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), target_segments=['LNK100_1']),
#  'DMR_VERT_POS_1': Segment(start_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), end_point=numpy.datetime64('2024-03-08T00:01:10.107000000'), target_segments=['LNK100_1']),
#  'DMR_VERT_POS_2': Segment(start_point=numpy.datetime64('2024-03-08T00:01:10.107000000'), end_point=numpy.datetime64('2024-03-08T00:01:24.907000000'), target_segments=['LNK100_1']),
#  'DMR_VERT_POS_3': Segment(start_point=numpy.datetime64('2024-03-08T00:01:24.907000000'), end_point=numpy.datetime64('2024-03-08T00:01:29.457000000'), target_segments=['LNK100_1']),
#  'DMR_VERT_POS_4': Segment(start_point=numpy.datetime64('2024-03-08T00:01:29.457000000'), end_point=numpy.datetime64('2024-03-08T00:01:36.507000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_0': Segment(start_point=numpy.datetime64('2024-03-07T23:59:28.907000000'), end_point=numpy.datetime64('2024-03-07T23:59:30.057000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_1': Segment(start_point=numpy.datetime64('2024-03-07T23:59:30.057000000'), end_point=numpy.datetime64('2024-03-07T23:59:33.107000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_2': Segment(start_point=numpy.datetime64('2024-03-07T23:59:33.107000000'), end_point=numpy.datetime64('2024-03-07T23:59:53.057000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_3': Segment(start_point=numpy.datetime64('2024-03-07T23:59:53.057000000'), end_point=numpy.datetime64('2024-03-07T23:59:55.457000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_4': Segment(start_point=numpy.datetime64('2024-03-07T23:59:55.457000000'), end_point=numpy.datetime64('2024-03-08T00:00:08.907000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_5': Segment(start_point=numpy.datetime64('2024-03-08T00:00:08.907000000'), end_point=numpy.datetime64('2024-03-08T00:00:10.207000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_6': Segment(start_point=numpy.datetime64('2024-03-08T00:00:10.207000000'), end_point=numpy.datetime64('2024-03-08T00:00:30.957000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_7': Segment(start_point=numpy.datetime64('2024-03-08T00:00:30.957000000'), end_point=numpy.datetime64('2024-03-08T00:00:32.607000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_8': Segment(start_point=numpy.datetime64('2024-03-08T00:00:32.607000000'), end_point=numpy.datetime64('2024-03-08T00:00:54.757000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_9': Segment(start_point=numpy.datetime64('2024-03-08T00:00:54.757000000'), end_point=numpy.datetime64('2024-03-08T00:01:04.107000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_10': Segment(start_point=numpy.datetime64('2024-03-08T00:01:04.107000000'), end_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_11': Segment(start_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), end_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_12': Segment(start_point=numpy.datetime64('2024-03-08T00:01:07.607000000'), end_point=numpy.datetime64('2024-03-08T00:01:09.907000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_13': Segment(start_point=numpy.datetime64('2024-03-08T00:01:09.907000000'), end_point=numpy.datetime64('2024-03-08T00:01:10.107000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_14': Segment(start_point=numpy.datetime64('2024-03-08T00:01:10.107000000'), end_point=numpy.datetime64('2024-03-08T00:01:14.507000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_15': Segment(start_point=numpy.datetime64('2024-03-08T00:01:14.507000000'), end_point=numpy.datetime64('2024-03-08T00:01:23.407000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_16': Segment(start_point=numpy.datetime64('2024-03-08T00:01:23.407000000'), end_point=numpy.datetime64('2024-03-08T00:01:24.907000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_17': Segment(start_point=numpy.datetime64('2024-03-08T00:01:24.907000000'), end_point=numpy.datetime64('2024-03-08T00:01:25.057000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_18': Segment(start_point=numpy.datetime64('2024-03-08T00:01:25.057000000'), end_point=numpy.datetime64('2024-03-08T00:01:29.307000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_19': Segment(start_point=numpy.datetime64('2024-03-08T00:01:29.307000000'), end_point=numpy.datetime64('2024-03-08T00:01:29.457000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_20': Segment(start_point=numpy.datetime64('2024-03-08T00:01:29.457000000'), end_point=numpy.datetime64('2024-03-08T00:01:36.507000000'), target_segments=['LNK100_1']),
#  'ALL_PTS_21': Segment(start_point=numpy.datetime64('2024-03-08T00:01:36.507000000'), end_point=numpy.datetime64('2024-03-08T00:01:36.707000000'), target_segments=['LNK100_1'])}

# %%
some = SecondaryFunctions().convert_date_columns_to_numeric(piroset, [{"name": "moment"}])

# %%
piroset.data["WBF_PIRO_1_moment_ni"].values
# Out:
# array(['2024-03-07T23:59:24.507000000', '2024-03-07T23:59:24.557000000',
#        '2024-03-07T23:59:24.607000000', ...,
#        '2024-03-08T00:01:38.907000000', '2024-03-08T00:01:38.957000000',
#        '2024-03-08T00:01:39.007000000'], dtype='datetime64[ns]')

# %%
some.data["WBF_PIRO_1_moment_ni"].values
# Out:
# array([0.00000000e+00, 5.00000715e-02, 1.00000024e-01, ...,
#        1.34400000e+02, 1.34450000e+02, 1.34500000e+02])

# %% [markdown]
# ### SegmentsAggregator Class

# %%
class AggregatedValue:

    def __init__(
        self,
        segment_id: str,
        transcription: Transcription,
        value: Optional[float],
        is_bad: bool = False,
        bad_reason: str = None
    ):
        self.segment_id = segment_id
        self.transcription = transcription
        self.value = value
        self.is_bad = is_bad
        self.bad_reason = bad_reason

    def __repr__(self):
        return f"{str(self.transcription)}, value={self.value}"


class AggregatedSegment(dict):

    def __init__(
        self,
        name: str,
        start_point: float,
        end_point: float,
        values: Dict[str, AggregatedValue] = ()
    ):
        self._name = name
        self._start_point = start_point
        self._end_point = end_point
        super(AggregatedSegment, self).__init__(values)

    def append_value(self, values: List[AggregatedValue]):
        for value in values:
            self[str(value.transcription)] = value

    def name(self):
        return self._name

    def start_point(self):
        return self._start_point

    def end_point(self):
        return self._end_point


class AggregatedSourceDict(dict):

    def __init__(
        self,
        settings: SourceSettings,
        segments: Dict[str, AggregatedSegment] = ()
    ):
        super(AggregatedSourceDict, self).__init__(segments)
        self._source = settings.source
        self._is_target = True if settings.type == 'target' else False
        self._settings = settings

    def __repr__(self):
        count_bad = sum(
            [
                1 for seg_vals in self.values() for value in seg_vals.values()
                if value.is_bad
            ]
        )
        count_values = sum(len(seg_vals) for seg_vals in self.values())
        return f"AggregatedSource(total_values={count_values}, " \
               f"bad_values={count_bad})"

    def append_segment(self, segment: AggregatedSegment):
        self[segment.name()] = segment

    def source(self):
        return self._source

    def settings(self):
        return self._settings

    def is_target(self):
        return self._is_target

class SegmentsAggregator:

    def __init__(self):
        self.methods = {
            "median": self.median_aggregate,
            "min": self.min_aggregate,
            "max": self.max_aggregate,
            "mean": self.mean_aggregate,
            "tg": self.tg_aggregate,
        }

    @staticmethod
    def return_segment_values(
        segment: Segment, billet_array: Array, data_array: Array
    ) -> np.array:
        # Начальная точка
        if segment.start_point < 0:
            start_point = max(billet_array.values) + segment.start_point
        else:
            start_point = segment.start_point

        # Конечная точка
        if segment.end_point == "end":
            end_point = max(billet_array.values)
        elif segment.end_point < 0:
            end_point = max(billet_array.values) + segment.end_point
        else:
            end_point = segment.end_point

        # Сегментация
        points = billet_array.values[(billet_array.values < 3)
                                     & (billet_array.values > 0)]
        segment_data = [
            value for bil, value in zip(billet_array.values, data_array.values)
            if end_point >= bil >= start_point
        ]
        return np.array(points), np.array(segment_data)

    def get_method_value(
        self,
        segment_id: str,
        transcription: Transcription,
        method: str,
        *args,
        **kwargs,
    ) -> AggregatedValue:
        return AggregatedValue(
            segment_id, transcription, self.methods[method](*args, **kwargs)
        )

    @staticmethod
    def median_aggregate(data_array: np.array):
        return np.median(data_array)

    @staticmethod
    def max_aggregate(data_array: np.array):
        return np.max(data_array)

    @staticmethod
    def min_aggregate(data_array: np.array):
        return np.min(data_array)

    @staticmethod
    def mean_aggregate(data_array: np.array):
        return np.mean(data_array)

    @staticmethod
    def tg_aggregate(data_array: np.array, points: np.array):
        extended_points = np.c_[points, np.ones(len(points))]
        tg, _ = np.linalg.lstsq(extended_points, data_array, rcond=None)[0]

        return tg

    def _rotate(self, data_array: np.array, points: np.array):
        angle = np.arctan(self.tg_aggregate(data_array, points))

        rotation_matrix = np.array(
            [[np.cos(angle), -np.sin(angle)], [np.sin(angle),
                                               np.cos(angle)]]
        )

        # Смещаем график к началу координат
        x_centered = points - np.mean(points)
        y_centered = data_array - np.mean(data_array)

        # Поворачиваем график
        xy_rotated = np.dot(
            rotation_matrix, np.vstack([x_centered, y_centered])
        )

        # Возвращаем график в исходное положение
        rotated_points = xy_rotated[0] + np.mean(points)
        rotated_array = xy_rotated[1] + np.mean(data_array)

        return rotated_points, rotated_array

# %%
# Создание объекта SourceSettings
settings = SourceSettings(
    source="LNK100",
    type="feature",
    handler="BASE",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[]),
            "LNK100_2": Segment(start_point=3, end_point=6, target_segments=["LNK100_1"]),
            "LNK100_3": Segment(start_point=30, end_point=70, target_segments=["LNK100_1"]),
            "LNK100_4": Segment(start_point=-3, end_point="end", target_segments=["LNK100_1"]),
            "LNK100_5": Segment(start_point=-6, end_point=-3, target_segments=["LNK100_1"])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['tg', 'max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)
# Создание объекта SourceDataset
dataset = SourceDataset(settings)

file_path = "testing/20240308000407_21046X404_IPSRNK_1_L.csv"
df = pd.read_csv(file_path, sep=';')
for col in df.columns:
    if col == "BilletPoints":
        df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce").fillna(0).astype(float)
    else:
        df[col] = pd.to_numeric(df[col].replace(",", "."), errors="coerce").fillna(0).astype(float)

dataset.append_dataframe_to_source_data(df)

# %%
pd.DataFrame(dataset.data["LNK100_1_Vert1000_ni"].values, columns={"Vert1000"})
# Out:
#       Vert1000
# 0        181.0
# 1        181.0
# 2        181.0
# 3        181.0
# 4        181.0
# ...        ...
# 4182       0.0
# 4183       0.0
# 4184       0.0
# 4185       0.0
# 4186       0.0
#
# [4187 rows x 1 columns]

# %%
points, seg_data = SegmentsAggregator().return_segment_values(dataset.settings.segments["LNK100_1"], dataset.billet_array(), dataset.data["LNK100_1_Vert1000_ni"])

# %%
points = [0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  , 0.225,
       0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425, 0.45 ,
       0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 , 0.675,
       0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875, 0.9  ,
       0.925, 0.95 , 0.975, 1.   , 1.025, 1.05 , 1.075, 1.1  , 1.125,
       1.15 , 1.175, 1.2  , 1.225, 1.25 , 1.275, 1.3  , 1.325, 1.35 ,
       1.375, 1.4  , 1.425, 1.45 , 1.475, 1.5  , 1.525, 1.55 , 1.575,
       1.6  , 1.625, 1.65 , 1.675, 1.7  , 1.725, 1.75 , 1.775, 1.8  ,
       1.825, 1.85 , 1.875, 1.9  , 1.925, 1.95 , 1.975, 2.   , 2.025,
       2.05 , 2.075, 2.1  , 2.125, 2.15 , 2.175, 2.2  , 2.225, 2.25 ,
       2.275, 2.3  , 2.325, 2.35 , 2.375, 2.4  , 2.425, 2.45 , 2.475,
       2.5  , 2.525, 2.55 , 2.575, 2.6  , 2.625, 2.65 , 2.675, 2.7  ,
       2.725, 2.75 , 2.775, 2.8  , 2.825, 2.85 , 2.875, 2.9  , 2.925,
       2.95 , 2.975]
len(points)
# Out:
# 119

# %%
seg_data = [181., 181., 181., 181., 181., 181., 181., 181., 181., 181.,
       181., 181., 181., 181., 181., 181., 181., 181., 181., 184., 187.,
       189., 191., 192., 193., 195., 195., 194., 194., 194., 194., 194.,
       194., 191., 189., 185., 183., 179., 177., 175., 172., 171., 170.,
       168., 168., 167., 167., 168., 167., 167., 167., 166., 163., 160.,
       158., 155., 153., 148., 143., 139., 134., 131., 129., 126., 123.,
       121., 119., 118., 118., 118., 118., 120., 121., 125., 128., 131.,
       134., 135., 134., 133., 134., 133., 135., 134., 135., 136., 135.,
       135., 136., 136., 135., 135., 136., 137., 135., 134., 133., 135.,
       136., 136., 136., 137., 137., 137., 137., 135., 134., 133., 133.,
       131., 131., 128., 126., 122., 118., 116., 114., 114., 115.]
len(seg_data)
# Out:
# 119

# %%
SegmentsAggregator()._rotate(seg_data, points)
# Out:
# (array([ 28.67729317,  28.67823394,  28.6791747 ,  28.68011547,
#          28.68105624,  28.68199701,  28.68293778,  28.68387855,
#          28.68481932,  28.68576009,  28.68670085,  28.68764162,
#          28.68858239,  28.68952316,  28.69046393,  28.6914047 ,
#          28.69234547,  28.69328624,  28.694227  ,  31.69304291,
#          34.69185882,  36.69138301,  38.6909072 ,  39.69113969,
#          40.69137217,  42.69089636,  42.69183713,  41.69348619,
#          41.69442695,  41.69536772,  41.69630849,  41.69724926,
#          41.69819003,  38.70125566,  36.703613  ,  32.70738692,
#          30.70974427,  26.71351818,  24.71587553,  22.71823287,
#          19.7212985 ,  18.72294756,  17.72459661,  15.72695396,
#          15.72789473,  14.72954378,  14.73048455,  15.73071703,
#          14.73236609,  14.73330686,  14.73424763,  13.73589668,
#          10.73896231,   7.74202794,   5.74438529,   2.74745092,
#           0.74980826,  -4.24570953,  -9.24122733, -13.23745341,
#         -18.2329712 , -21.22990557, -23.22754823, -26.2244826 ,
#         -29.22141697, -31.21905962, -33.21670228, -34.21505322,
#         -34.21411245, -34.21317169, -34.21223092, -32.21270672,
#         -31.21247424, -27.21436662, -24.21555072, -21.21673481,
#         -18.2179189 , -17.21768642, -18.21603737, -19.21438831,
#         -18.21415583, -19.21250677, -17.21298258, -18.21133352,
#         -17.21110104, -16.21086856, -17.2092195 , -17.20827874,
#         -16.20804625, -16.20710549, -17.20545643, -17.20451566,
#         -16.20428318, -15.2040507 , -17.20169335, -18.2000443 ,
#         -19.19839524, -17.19887105, -16.19863857, -16.1976978 ,
#         -16.19675703, -15.19652455, -15.19558378, -15.19464301,
#         -15.19370224, -17.1913449 , -18.18969584, -19.18804679,
#         -19.18710602, -21.18474867, -21.18380791, -24.18074227,
#         -26.17838493, -30.17461101, -34.17083709, -36.16847975,
#         -38.16612241, -38.16518164, -37.16494916]),
#  array([156.24737137, 156.22238907, 156.19740678, 156.17242449,
#         156.14744219, 156.1224599 , 156.09747761, 156.07249532,
#         156.04751302, 156.02253073, 155.99754844, 155.97256614,
#         155.94758385, 155.92260156, 155.89761927, 155.87263697,
#         155.84765468, 155.82267239, 155.79769009, 155.88560004,
#         155.97350999, 156.0237892 , 156.0740684 , 156.08671685,
#         156.09936531, 156.14964451, 156.12466222, 156.06204918,
#         156.03706689, 156.01208459, 155.9871023 , 155.96212001,
#         155.93713771, 155.79926318, 155.69901939, 155.52351411,
#         155.42327032, 155.24776504, 155.14752125, 155.04727746,
#         154.90940292, 154.84678988, 154.78417684, 154.68393305,
#         154.65895076, 154.59633772, 154.57135543, 154.58400388,
#         154.52139084, 154.49640855, 154.47142626, 154.40881322,
#         154.27093868, 154.13306415, 154.03282036, 153.89494582,
#         153.79470203, 153.581566  , 153.36842997, 153.19292469,
#         152.97978866, 152.84191412, 152.74167033, 152.6037958 ,
#         152.46592126, 152.36567747, 152.26543369, 152.20282065,
#         152.17783835, 152.15285606, 152.12787377, 152.17815297,
#         152.19080142, 152.31634212, 152.40425207, 152.49216202,
#         152.58007197, 152.59272043, 152.53010739, 152.46749435,
#         152.4801428 , 152.41752976, 152.46780896, 152.40519592,
#         152.41784438, 152.43049283, 152.36787979, 152.3428975 ,
#         152.35554595, 152.33056366, 152.26795062, 152.24296833,
#         152.25561678, 152.26826524, 152.16802145, 152.10540841,
#         152.04279537, 152.09307457, 152.10572303, 152.08074073,
#         152.05575844, 152.06840689, 152.0434246 , 152.01844231,
#         151.99346002, 151.89321623, 151.83060319, 151.76799015,
#         151.74300785, 151.64276407, 151.61778177, 151.47990724,
#         151.37966345, 151.20415817, 151.02865288, 150.92840909,
#         150.82816531, 150.80318301, 150.81583147]))

# %%
dataset.settings.segments
# Out:
# {'LNK100_1': Segment(start_point=0, end_point=3, target_segments=[]),
#  'LNK100_2': Segment(start_point=3, end_point=6, target_segments=['LNK100_1']),
#  'LNK100_3': Segment(start_point=30, end_point=70, target_segments=['LNK100_1']),
#  'LNK100_4': Segment(start_point=-3, end_point='end', target_segments=['LNK100_1']),
#  'LNK100_5': Segment(start_point=-6, end_point=-3, target_segments=['LNK100_1'])}

# %%
dataset.data
# Out:
# {'LNK100_1_BilletPoints_ni': LNK100_1_BilletPoints_ni; is_numeric=True, is_billet=True,
#  'LNK100_1_Vert1000_ni': LNK100_1_Vert1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Vert1500_ni': LNK100_1_Vert1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Vert2000_ni': LNK100_1_Vert2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Vert3000_ni': LNK100_1_Vert3000_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Hor1000_ni': LNK100_1_Hor1000_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Hor1500_ni': LNK100_1_Hor1500_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Hor2000_ni': LNK100_1_Hor2000_ni; is_numeric=True, is_billet=False,
#  'LNK100_1_Torsion_ni': LNK100_1_Torsion_ni; is_numeric=True, is_billet=False}

# %%
seg = SegmentsAggregator()

# %%
some = np.array(dataset.data["LNK100_1_Hor1000_ni"].values)

# %%
np.median(some)
# Out:
# 90.0

# %%
agg_median = AggregatedValue("some", dataset.data["LNK100_1_Hor1000_ni"].transcription, value=0)

agg_median = seg.get_method_value("some", dataset.data["LNK100_1_Hor1000_ni"].transcription, seg.median_aggregate(dataset.data["LNK100_1_Hor1000_ni"].values))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[869], line 3
#       1 agg_median = AggregatedValue("some", dataset.data["LNK100_1_Hor1000_ni"].transcription, value=0)
# ----> 3 agg_median = seg.get_method_value("some", dataset.data["LNK100_1_Hor1000_ni"].transcription, seg.median_aggregate(dataset.data["LNK100_1_Hor1000_ni"].values))
#
# Cell In[845], line 131, in SegmentsAggregator.get_method_value(self, segment_id, transcription, method, *args, **kwargs)
#     122 def get_method_value(
#     123     self,
#     124     segment_id: str,
#    (...)
#     128     **kwargs,
#     129 ) -> AggregatedValue:
#     130     return AggregatedValue(
# --> 131         segment_id, transcription, self.methods[method](*args, **kwargs)
#     132     )
#
# KeyError: 90.0

# %%
dataset.settings.segments["LNK100_1"].start_point
# Out:
# 0

# %%
agg_seg = AggregatedSegment(
    "LNK100_1_Hor1000_ni_median",
    dataset.settings.segments["LNK100_1"].start_point,
    dataset.settings.segments["LNK100_1"].end_point,
)

agg_seg.append_value([seg.get_method_value("some",
                     dataset.data["LNK100_1_Hor1000_ni"].transcription,
                     seg.median_aggregate(dataset.data["LNK100_1_Hor1000_ni"].values))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[878], line 7
#       1 agg_seg = AggregatedSegment(
#       2     "LNK100_1_Hor1000_ni_median",
#       3     dataset.settings.segments["LNK100_1"].start_point,
#       4     dataset.settings.segments["LNK100_1"].end_point,
#       5 )
# ----> 7 seg.get_method_value("some",
#       8                      dataset.data["LNK100_1_Hor1000_ni"].transcription,
#       9                      seg.median_aggregate(dataset.data["LNK100_1_Hor1000_ni"].values))
#      11 agg_seg.append_value([seg.get_method_value("some",
#      12                      dataset.data["LNK100_1_Hor1000_ni"].transcription,
#      13                      seg.median_aggregate(dataset.data["LNK100_1_Hor1000_ni"].values))])
#
# Cell In[845], line 131, in SegmentsAggregator.get_method_value(self, segment_id, transcription, method, *args, **kwargs)
#     122 def get_method_value(
#     123     self,
#     124     segment_id: str,
#    (...)
#     128     **kwargs,
#     129 ) -> AggregatedValue:
#     130     return AggregatedValue(
# --> 131         segment_id, transcription, self.methods[method](*args, **kwargs)
#     132     )
#
# KeyError: 90.0

# %% [markdown]
# ### Fliters Class

# %%
class Filters:

    def __init__(self):
        self.methods = {
            "std": self.remove_by_std,
            "forbidden_columns": self.remove_by_forbidden_columns
        }

    def filter_by(self, method: str, *args, **kwargs):
        return self.methods[method](*args, **kwargs)

    @staticmethod
    def remove_by_std(data_array: Array, *args, **kwargs):
        if data_array.is_numeric:
            return True if data_array.values.std() == 0 else False
        else:
            return False

    @staticmethod
    def remove_by_forbidden_columns(
        data_array: Array,
        source_data: SourceDataset,
        *args,
        **kwargs,
    ):
        if (data_array.transcription.name
                in source_data.settings.forbidden_columns):
            return True
        else:
            return False

# %% [markdown]
# ### HandlerFactory Class

# %%
from abc import ABC, abstractmethod

class SourceHandler(ABC):
    source: str

    @abstractmethod
    def __init__(
        self, features_generator: FeaturesGenerator, filters: Filters,
        secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator
    ):
        self.segments_aggregator = segments_aggregator
        self.secondary_functions = secondary_functions
        self.feature_generator = features_generator
        self.filters = filters

    @abstractmethod
    def process_pipeline(
        self, billet_id: str, data: pd.DataFrame, settings: SourceSettings
    ):
        ...

# %%
class HandlersFactory:

    def __init__(
        self, features_generator: FeaturesGenerator, filters: Filters,
        materials: Materials, secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator
    ):
        handler_setup = {
            "features_generator": features_generator,
            "filters": filters,
            "secondary_functions": secondary_functions,
            "segments_aggregator": segments_aggregator,
            "materials": materials
        }
        self.handlers_dict = {
            BASEHandler.source: BASEHandler(**handler_setup),
            BASEWITHPOINTSHandler.source: BASEHandler(**handler_setup),
            WBFPIROHandler.source: WBFPIROHandler(**handler_setup),
            WBFSINGLEHandler.source: WBFSINGLEHandler(**handler_setup)
        }

    def get_handler(self, source: str) -> SourceHandler:
        return self.handlers_dict[source]

# %% [markdown]
# ### BASEHandler Class

# %%
class BASEHandler(SourceHandler):
    source = "BASE"

    def __init__(
        self,
        features_generator: FeaturesGenerator,
        filters: Filters,
        materials: Materials,
        secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator,
    ):
        self.materials = materials
        self.segments_aggregator = segments_aggregator
        self.secondary_functions = secondary_functions
        self.feature_generator = features_generator
        self.filters = filters

    def process_pipeline(
        self, billet_id: str, data: pd.DataFrame, settings: SourceSettings
    ) -> AggregatedSourceDict:
        source_data = SourceDataset(settings)

        # Подготовительный пайплайн
        source_data.append_dataframe_to_source_data(data)
        source_data = (
            self.secondary_functions.
            sort_dataset_ascending_by_billet(source_data)
        )
        source_data = self.secondary_functions.approximate_billet_by_bounds(
            source_data
        )
        with open(self.materials.PATHS['workcenters']) as handle:
            workcenters = json.load(handle)
        source_data = (
            self.secondary_functions.append_workcenter_to_transcription(
                source_data, workcenters
            )
        )

        # Базовый пайплайн
        source_data = self.filter_data(source_data)
        source_data = self.generate_features(source_data)
        aggregated_source = self.calculate_aggregations(source_data)
        return aggregated_source

    def filter_data(self, source_data: SourceDataset) -> SourceDataset:
        """Фильтрация данных"""
        filtered_columns = []
        for data_array in source_data:
            if data_array.is_billet:
                continue
            for method in [*source_data.settings.filtration_methods,
                           "forbidden_columns"]:
                is_bad = self.filters.filter_by(
                    method=method,
                    data_array=data_array,
                    source_data=source_data
                )
                if is_bad:
                    filtered_columns.append(data_array.transcription)
        source_data.remove_arrays(filtered_columns)
        return source_data

    def generate_features(self, source_data: SourceDataset) -> SourceDataset:
        """Генерация вторичных фичей"""
        new_arrays = []
        for method in source_data.settings.secondary_features:
            for data_array in source_data:
                if data_array.is_billet or not data_array.is_numeric:
                    continue
                new_arrays.append(
                    self.feature_generator.get_method_values(
                        method, data_array
                    )
                )
        for new_array in new_arrays:
            source_data.append_array_to_source_data(new_array)
        return source_data

    def calculate_aggregations(
        self, source_data: SourceDataset
    ) -> AggregatedSourceDict:
        """Аггрегация данных по сегментам"""
        aggregated_source = AggregatedSourceDict(source_data.settings)
        for segment_id, segment in source_data.settings.segments.items():
            aggregated_segment = AggregatedSegment(
                segment_id, segment.start_point, segment.end_point
            )
            for data_array in source_data:
                if data_array.is_billet:
                    continue
                for method in source_data.settings.aggregation_methods:
                    transcription = data_array.transcription.add_tags(
                        {
                            "sector_range": [
                                f"{segment.start_point}_{segment.end_point}"
                            ],
                            "aggregation": [f"{method}"]
                        }
                    )
                    segment_values = (
                        self.segments_aggregator.return_segment_values(
                            segment, source_data.billet_array(), data_array
                        )
                    )
                    segment_values = segment_values[~pd.isnull(segment_values)]
                    if not data_array.is_numeric:
                        aggregated_value = AggregatedValue(
                            segment_id,
                            transcription,
                            None,
                            True,
                            "Not numeric",
                        )
                    elif len(segment_values) == 0:
                        aggregated_value = AggregatedValue(
                            segment_id, transcription, None, True, "Empty"
                        )
                    else:
                        aggregated_value = (
                            self.segments_aggregator.get_method_value(
                                segment_id, transcription, method,
                                segment_values
                            )
                        )
                    aggregated_segment.append_value([aggregated_value])
            aggregated_source.append_segment(aggregated_segment)
        return aggregated_source

# %% [markdown]
# ### BASEWITHPOINTSHandler

# %%
class BASEWITHPOINTSHandler(SourceHandler):
    source = "BASEWITHPOINTS"

    def __init__(
        self,
        features_generator: FeaturesGenerator,
        filters: Filters,
        materials: Materials,
        secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator,
    ):
        self.materials = materials
        self.segments_aggregator = segments_aggregator
        self.secondary_functions = secondary_functions
        self.feature_generator = features_generator
        self.filters = filters

    def process_pipeline(
        self, billet_id: str, data: pd.DataFrame, settings: SourceSettings
    ) -> AggregatedSourceDict:
        source_data = SourceDataset(settings)

        # Подготовительный пайплайн
        source_data.append_dataframe_to_source_data(data)
        source_data = (
            self.secondary_functions.
            sort_dataset_ascending_by_billet(source_data)
        )
        source_data = self.secondary_functions.approximate_billet_by_bounds(
            source_data
        )
        with open(self.materials.PATHS['workcenters']) as handle:
            workcenters = json.load(handle)

        with open(self.materials.PATHS['min_data']) as handle:
            MIN = json.load(handle)

        with open(self.materials.PATHS['max_data']) as handle:
            MAX = json.load(handle)

        source_data = (
            self.secondary_functions.append_workcenter_to_transcription(
                source_data, workcenters
            )
        )

        # Базовый пайплайн
        source_data = self.filter_data(source_data)
        source_data = self.generate_features(source_data, MIN, MAX)
        aggregated_source = self.calculate_aggregations(source_data)
        return aggregated_source

    def filter_data(self, source_data: SourceDataset) -> SourceDataset:
        """Фильтрация данных"""
        filtered_columns = []
        for data_array in source_data:
            if data_array.is_billet:
                continue
            for method in [*source_data.settings.filtration_methods,
                           "forbidden_columns"]:
                is_bad = self.filters.filter_by(
                    method=method,
                    data_array=data_array,
                    source_data=source_data
                )
                if is_bad:
                    filtered_columns.append(data_array.transcription)
        source_data.remove_arrays(filtered_columns)
        return source_data

    def generate_features(
        self, source_data: SourceDataset, MIN, MAX
    ) -> SourceDataset:
        """Генерация вторичных фичей"""
        new_arrays = []
        for method in source_data.settings.secondary_features:
            for data_array in source_data:
                if data_array.is_billet or not data_array.is_numeric:
                    continue
                new_arrays.append(
                    self.feature_generator.get_method_values(
                        method, data_array, MIN, MAX
                    )
                )
        for new_array in new_arrays:
            source_data.append_array_to_source_data(new_array)
        return source_data

    def calculate_aggregations(
        self, source_data: SourceDataset
    ) -> AggregatedSourceDict:
        """Аггрегация данных по сегментам"""
        aggregated_source = AggregatedSourceDict(source_data.settings)
        for segment_id, segment in source_data.settings.segments.items():
            aggregated_segment = AggregatedSegment(
                segment_id, segment.start_point, segment.end_point
            )
            for data_array in source_data:
                if data_array.is_billet:
                    continue
                for method in source_data.settings.aggregation_methods:
                    transcription = data_array.transcription.add_tags(
                        {
                            "sector_range": [
                                f"{segment.start_point}_{segment.end_point}"
                            ],
                            "aggregation": [f"{method}"]
                        }
                    )

                    points, segment_values = (
                        self.segments_aggregator.return_segment_values(
                            segment, source_data.billet_array(), data_array
                        )
                    )
                    nan_indexes = np.where(np.isnan(segment_values))
                    segment_values = segment_values[~np.isnan(segment_values)]
                    points = np.delete(points, nan_indexes)
                    segment_values = segment_values[~pd.isnull(segment_values)]

                    if not data_array.is_numeric:
                        aggregated_value = AggregatedValue(
                            segment_id,
                            transcription,
                            None,
                            True,
                            "Not numeric",
                        )
                    elif len(segment_values) == 0:
                        aggregated_value = AggregatedValue(
                            segment_id, transcription, None, True, "Empty"
                        )
                    else:
                        aggregated_value = (
                            self.segments_aggregator.get_method_value(
                                segment_id, transcription, method,
                                segment_values, points
                            )
                        )
                    aggregated_segment.append_value([aggregated_value])
            aggregated_source.append_segment(aggregated_segment)
        return aggregated_source

# %% [markdown]
# ### WBFPIROHandler

# %%
class WBFPIROHandler(SourceHandler):
    source = "WBFPIRO"

    def __init__(
        self,
        features_generator: FeaturesGenerator,
        filters: Filters,
        materials: Materials,
        secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator,
    ):
        self.materials = materials
        self.segments_aggregator = segments_aggregator
        self.secondary_functions = secondary_functions
        self.feature_generator = features_generator
        self.filters = filters

    def process_pipeline(
        self, billet_id: str, data: pd.DataFrame, settings: SourceSettings
    ) -> AggregatedSourceDict:
        source_data = SourceDataset(settings)

        # Подготовительный пайплайн
        source_data.append_dataframe_to_source_data(data)
        source_data = self.secondary_functions.convert_date_columns_to_numeric(
            source_data, [{
                "name": "moment"
            }]
        )
        with open(self.materials.PATHS['wbf_piro_cutter_settings']) as handle:
            wbf_piro_cutter_settings = json.load(handle)
        source_data = self.secondary_functions.cut_wbf_pirometer_signals(
            source_data, wbf_piro_cutter_settings
        )
        source_data = (
            self.secondary_functions.
            sort_dataset_ascending_by_billet(source_data)
        )
        with open(self.materials.PATHS['workcenters']) as handle:
            workcenters = json.load(handle)
        source_data = (
            self.secondary_functions.append_workcenter_to_transcription(
                source_data, workcenters
            )
        )

        # Базовый пайплайн
        source_data = self.filter_data(source_data)
        source_data = self.generate_features(source_data)
        aggregated_source = self.calculate_aggregations(source_data)
        return aggregated_source

    def filter_data(self, source_data: SourceDataset) -> SourceDataset:
        """Фильтрация данных"""
        filtered_columns = []
        for data_array in source_data:
            if data_array.is_billet:
                continue
            for method in [*source_data.settings.filtration_methods,
                           "forbidden_columns"]:
                is_bad = self.filters.filter_by(
                    method=method,
                    data_array=data_array,
                    source_data=source_data
                )
                if is_bad:
                    filtered_columns.append(data_array.transcription)
        source_data.remove_arrays(filtered_columns)
        return source_data

    def generate_features(self, source_data: SourceDataset) -> SourceDataset:
        """Генерация вторичных фичей"""
        new_arrays = []
        for method in source_data.settings.secondary_features:
            for data_array in source_data:
                if data_array.is_billet or not data_array.is_numeric:
                    continue
                new_arrays.append(
                    self.feature_generator.get_method_values(
                        method, data_array
                    )
                )
        for new_array in new_arrays:
            source_data.append_array_to_source_data(new_array)
        return source_data

    def calculate_aggregations(
        self, source_data: SourceDataset
    ) -> AggregatedSourceDict:
        """Аггрегация данных по сегментам"""
        aggregated_source = AggregatedSourceDict(source_data.settings)
        for segment_id, segment in source_data.settings.segments.items():
            aggregated_segment = AggregatedSegment(
                segment_id, segment.start_point, segment.end_point
            )
            for data_array in source_data:
                if data_array.is_billet:
                    continue
                for method in source_data.settings.aggregation_methods:
                    transcription = data_array.transcription.add_tags(
                        {
                            "sector_range": [f"{segment_id}"],
                            "aggregation": [f"{method}"]
                        }
                    )
                    segment_values = (
                        self.segments_aggregator.return_segment_values(
                            segment,
                            source_data.billet_array(),
                            data_array,
                        )
                    )
                    segment_values = segment_values[~pd.isnull(segment_values)]
                    if not data_array.is_numeric:
                        aggregated_value = AggregatedValue(
                            segment_id,
                            transcription,
                            None,
                            True,
                            "Not numeric",
                        )
                    elif len(segment_values) == 0:
                        aggregated_value = AggregatedValue(
                            segment_id, transcription, None, True, "Empty"
                        )
                    else:
                        aggregated_value = (
                            self.segments_aggregator.get_method_value(
                                segment_id, transcription, method,
                                segment_values
                            )
                        )
                    aggregated_segment.append_value([aggregated_value])
            aggregated_source.append_segment(aggregated_segment)
        return aggregated_source

# %% [markdown]
# ### WBFSINGLEHandler

# %%
class WBFSINGLEHandler(SourceHandler):
    source = "WBFSINGLE"

    def __init__(
        self,
        features_generator: FeaturesGenerator,
        filters: Filters,
        materials: Materials,
        secondary_functions: SecondaryFunctions,
        segments_aggregator: SegmentsAggregator,
    ):
        self.materials = materials
        self.segments_aggregator = segments_aggregator
        self.secondary_functions = secondary_functions
        self.feature_generator = features_generator
        self.filters = filters

    def process_pipeline(
        self, billet_id: str, data: pd.DataFrame, settings: SourceSettings
    ) -> AggregatedSourceDict:
        data = data[data[settings.billet_column
                         ].apply(lambda x: x[:-1] in billet_id)]
        data = data.sort_values(by=["CHARGING_TIME"])
        source_data = SourceDataset(settings)

        # Подготовительный пайплайн
        source_data.append_dataframe_to_source_data(data)

        # Базовый пайплайн
        source_data = self.filter_data(source_data)
        aggregated_source = self.calculate_aggregations(source_data)
        return aggregated_source

    def filter_data(self, source_data: SourceDataset) -> SourceDataset:
        """Фильтрация данных"""
        filtered_columns = []
        for data_array in source_data:
            if data_array.is_billet:
                continue
            for method in [*source_data.settings.filtration_methods,
                           "forbidden_columns"]:
                is_bad = self.filters.filter_by(
                    method=method,
                    data_array=data_array,
                    source_data=source_data
                )
                if is_bad:
                    filtered_columns.append(data_array.transcription)
        source_data.remove_arrays(filtered_columns)
        return source_data

    def calculate_aggregations(
        self, source_data: SourceDataset
    ) -> AggregatedSourceDict:
        """Аггрегация данных по сегментам"""
        aggregated_source = AggregatedSourceDict(source_data.settings)
        for segment_id, segment in source_data.settings.segments.items():
            aggregated_segment = AggregatedSegment(
                segment_id, segment.start_point, segment.end_point
            )
            for data_array in source_data:
                if data_array.is_billet:
                    continue
                transcription = data_array.transcription.add_tags(
                    {"sector_range": ["single"]}
                )
                if not data_array.is_numeric:
                    aggregated_value = AggregatedValue(
                        segment_id, transcription, None, True, "Not numeric"
                    )
                else:
                    aggregated_value = AggregatedValue(
                        segment_id, transcription, float(data_array.values[0])
                    )
                aggregated_segment.append_value([aggregated_value])
            aggregated_source.append_segment(aggregated_segment)
        return aggregated_source

# %%
from glob import glob
import os

PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

# Компоненты запуска процесса обработки файлов
materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# %%
# Параметры для обработки
billet_id = "BilletPoints"

file_path = "testing/20240308000407_21046X404_IPSRNK_1_L.csv"
df = pd.read_csv(file_path, sep=';')
for col in df.columns:
    if col == "BilletPoints":
        df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce").fillna(0).astype(float)
    else:
        df[col] = pd.to_numeric(df[col].replace(",", "."), errors="coerce").fillna(0).astype(float)

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="LNK100",
    type="feature",
    handler="BASE",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)

# Получение объекта BASEHandler
handler = handlers_factory.get_handler("BASE")

# Запуск обработки данных с помощью BASEHandler
result = handler.process_pipeline(billet_id, data, settings)

# %%
result
# Out:
# AggregatedSource(total_values=24, bad_values=0)

# %%
result['LNK100_1']
# Out:
# {'mill_LNK100_1_Hor1500_ni_0_3_max': mill_LNK100_1_Hor1500_ni_0_3_max, value=443.0,
#  'mill_LNK100_1_Hor1500_ni_0_3_min': mill_LNK100_1_Hor1500_ni_0_3_min, value=223.0,
#  'mill_LNK100_1_Hor1500_ni_0_3_median': mill_LNK100_1_Hor1500_ni_0_3_median, value=283.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_max': mill_LNK100_1_Hor2000_ni_0_3_max, value=719.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_min': mill_LNK100_1_Hor2000_ni_0_3_min, value=340.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_median': mill_LNK100_1_Hor2000_ni_0_3_median, value=492.0,
#  'mill_LNK100_1_Torsion_ni_0_3_max': mill_LNK100_1_Torsion_ni_0_3_max, value=468.0,
#  'mill_LNK100_1_Torsion_ni_0_3_min': mill_LNK100_1_Torsion_ni_0_3_min, value=2.0,
#  'mill_LNK100_1_Torsion_ni_0_3_median': mill_LNK100_1_Torsion_ni_0_3_median, value=275.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max, value=195.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min, value=114.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median, value=139.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max, value=203.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min, value=158.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median, value=191.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max, value=253.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min, value=208.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median, value=217.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max, value=397.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min, value=240.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median, value=327.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max, value=238.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min, value=122.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median, value=150.0}

# %%
result['LNK100_1']["mill_LNK100_1_Hor1500_ni_0_3_max"].transcription
# Out:
# mill_LNK100_1_Hor1500_ni_0_3_max

# %%
# Параметры для обработки
billet_id = "BilletPoints"

file_path = "testing/20240308000407_21046X404_IPSRNK_1_L.csv"
df = pd.read_csv(file_path, sep=';')
for col in df.columns:
    if col == "BilletPoints":
        df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce").fillna(0).astype(float)
    else:
        df[col] = pd.to_numeric(df[col].replace(",", "."), errors="coerce").fillna(0).astype(float)

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="LNK100",
    type="feature",
    handler="BASEWITHPOINTS",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)

# Получение объекта BASEHandler
handler = handlers_factory.get_handler("BASEWITHPOINTS")

# Запуск обработки данных с помощью BASEHandler
result = handler.process_pipeline(billet_id, data, settings)

# %%
result['LNK100_1']
# Out:
# {'mill_LNK100_1_Hor1500_ni_0_3_max': mill_LNK100_1_Hor1500_ni_0_3_max, value=443.0,
#  'mill_LNK100_1_Hor1500_ni_0_3_min': mill_LNK100_1_Hor1500_ni_0_3_min, value=223.0,
#  'mill_LNK100_1_Hor1500_ni_0_3_median': mill_LNK100_1_Hor1500_ni_0_3_median, value=283.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_max': mill_LNK100_1_Hor2000_ni_0_3_max, value=719.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_min': mill_LNK100_1_Hor2000_ni_0_3_min, value=340.0,
#  'mill_LNK100_1_Hor2000_ni_0_3_median': mill_LNK100_1_Hor2000_ni_0_3_median, value=492.0,
#  'mill_LNK100_1_Torsion_ni_0_3_max': mill_LNK100_1_Torsion_ni_0_3_max, value=468.0,
#  'mill_LNK100_1_Torsion_ni_0_3_min': mill_LNK100_1_Torsion_ni_0_3_min, value=2.0,
#  'mill_LNK100_1_Torsion_ni_0_3_median': mill_LNK100_1_Torsion_ni_0_3_median, value=275.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max, value=195.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min, value=114.0,
#  'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median, value=139.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max, value=203.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min, value=158.0,
#  'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median, value=191.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max, value=253.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min, value=208.0,
#  'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median, value=217.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max, value=397.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min, value=240.0,
#  'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median, value=327.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max, value=238.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min, value=122.0,
#  'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median, value=150.0}

# %%
from glob import glob
import os

PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

# Компоненты запуска процесса обработки файлов
materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# Параметры для обработки
billet_id = "moment"

file_path = 'testing/20240307170148_XX-Л210444041_WBF_1_T2.csv'
df = pd.read_csv(file_path, sep=';')
for col in df.drop("moment", axis=1).columns:
    df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce")
df["moment"] = pd.to_datetime(df["moment"])

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="WBF_PIRO",
    type="feature",
    handler="WBFPIRO",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="billet_pirometer_files",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_PIRO_1": Segment(start_point=0, end_point="end", target_segments=["LNK100_1"])
        },
    forbidden_columns=["BEAM_VERT_ENC", "BEAM_HOR_ENC_POS", "DM_ENC_HOR_POS", "DML_VERT_POS", "DMR_VERT_POS"],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=['max', 'min','median','mean'],
    billet_column="moment",
    convert_columns={}
)

# Указываем путь к файлу JSON
file_path = "exploration/agregator/run/materials/wbf_piro_cutter_settings.json"

# Открываем файл и загружаем его содержимое в переменную
with open(file_path, "r") as file:
    piro_settings = json.load(file)

# Получение объекта BASEHandler
handler = handlers_factory.get_handler("WBFPIRO")

# Запуск обработки данных с помощью BASEHandler
result = handler.process_pipeline(billet_id, data, settings)
# Out:
# [153, 469, 752, 1152, 1706]
# [495, 773, 1172, 1596]
# [1892, 2067]
# [77, 1772, 1816, 2098, 2183, 2326]
# [100, 1772, 1820, 2095, 2186, 2322]
# [77, 100, 153, 469, 495, 752, 773, 1152, 1172, 1596, 1706, 1772, 1772, 1816, 1820, 1892, 2067, 2095, 2098, 2183, 2186, 2322, 2326]

# %%
result["WBF_PIRO_1"]
# Out:
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max, value=1187.239501953125,
#  'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min, value=1107.1539306640625,
#  'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median, value=1183.767333984375,
#  'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean, value=1165.8901766886754,
#  'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max, value=1187.5867919921875,
#  'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min, value=1083.94091796875,
#  'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median, value=1185.9375,
#  'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean, value=1161.4180109833446,
#  'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max, value=1148.495361328125,
#  'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min, value=1090.4803466796875,
#  'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median, value=1140.3935546875,
#  'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean, value=1135.0946023830923}

# %%
from glob import glob
import os

PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

# Компоненты запуска процесса обработки файлов
materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# Параметры для обработки
billet_id = "Л210421011"

file_path = 'testing/20240308000000_20240309000000_WBF.csv'
# Чтение файла с указанием кодировки ANSI
df = pd.read_csv(file_path, sep=';', encoding='ANSI')
forbidden_cols = ["billet_number", "CHARGING_TIME", "IS_DISCHARGED"]
for col in df.columns:
    if col not in forbidden_cols:
        # Если тип столбца - строка, заменяем запятые на точки и преобразуем в числовой тип
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.')
            df[col] = pd.to_numeric(df[col], errors='coerce')
df = df.fillna(0)
data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="WBF_sgl",
    type="feature",
    handler="WBFSINGLE",
    rolling_number="1",
    encoding="ANSI",
    is_single=True,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "1": Segment(start_point=0, end_point=0, target_segments=["LNK100_1"])
        },
    forbidden_columns=[],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=[],
    billet_column="billet_number",
    convert_columns={}
)

# Получение объекта BASEHandler
handler = handlers_factory.get_handler("WBFSINGLE")

# Запуск обработки данных с помощью BASEHandler
result = handler.process_pipeline(billet_id, data, settings)

# %%
result["1"]
# Out:
# {'WBF_sgl_1_PIECE_PK_ni_single': WBF_sgl_1_PIECE_PK_ni_single, value=2.4030712380000006e+19,
#  'WBF_sgl_1_FURNACE_FK_ni_single': WBF_sgl_1_FURNACE_FK_ni_single, value=1.0,
#  'WBF_sgl_1_CHARGING_TIME_ni_single': WBF_sgl_1_CHARGING_TIME_ni_single, value=None,
#  'WBF_sgl_1_TOT_X_NODE_ni_single': WBF_sgl_1_TOT_X_NODE_ni_single, value=100.0,
#  'WBF_sgl_1_TOT_Y_NODE_ni_single': WBF_sgl_1_TOT_Y_NODE_ni_single, value=7.0,
#  'WBF_sgl_1_TOT_Z_NODE_ni_single': WBF_sgl_1_TOT_Z_NODE_ni_single, value=7.0,
#  'WBF_sgl_1_X_POS_ni_single': WBF_sgl_1_X_POS_ni_single, value=599.0,
#  'WBF_sgl_1_X_COORD_ni_single': WBF_sgl_1_X_COORD_ni_single, value=4540.5,
#  'WBF_sgl_1_IS_DISCHARGED_ni_single': WBF_sgl_1_IS_DISCHARGED_ni_single, value=None,
#  'WBF_sgl_1_DISCHARGING_TIME_ni_single': WBF_sgl_1_DISCHARGING_TIME_ni_single, value=0.0,
#  'WBF_sgl_1_MARKA_ni_single': WBF_sgl_1_MARKA_ni_single, value=0.0,
#  'WBF_sgl_1_BISRA_ni_single': WBF_sgl_1_BISRA_ni_single, value=5.0,
#  'WBF_sgl_1_STRATEGY_ni_single': WBF_sgl_1_STRATEGY_ni_single, value=1.0,
#  'WBF_sgl_1_L_WBF_ni_single': WBF_sgl_1_L_WBF_ni_single, value=7883.0,
#  'WBF_sgl_1_H_WBF_ni_single': WBF_sgl_1_H_WBF_ni_single, value=300.0,
#  'WBF_sgl_1_W_WBF_ni_single': WBF_sgl_1_W_WBF_ni_single, value=366.0,
#  'WBF_sgl_1_WEIGHT_ni_single': WBF_sgl_1_WEIGHT_ni_single, value=6789.0,
#  'WBF_sgl_1_CHG_TEMP_ni_single': WBF_sgl_1_CHG_TEMP_ni_single, value=25.0,
#  'WBF_sgl_1_PLA_PACE_RATE_ni_single': WBF_sgl_1_PLA_PACE_RATE_ni_single, value=117.0,
#  'WBF_sgl_1_CUR_PACE_RATE_ni_single': WBF_sgl_1_CUR_PACE_RATE_ni_single, value=147.0,
#  'WBF_sgl_1_TARGET_TEMP_ni_single': WBF_sgl_1_TARGET_TEMP_ni_single, value=1220.0,
#  'WBF_sgl_1_TARGET_TEMP_Cor_ni_single': WBF_sgl_1_TARGET_TEMP_Cor_ni_single, value=-57.0,
#  'WBF_sgl_1_DCHG_TARGET_TEMP_PDI_ni_single': WBF_sgl_1_DCHG_TARGET_TEMP_PDI_ni_single, value=1220.0,
#  'WBF_sgl_1_CALC_MEAN_TEMP_CNV_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_CNV_ni_single, value=108.0,
#  'WBF_sgl_1_CALC_MEAN_TEMP_PHE_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_PHE_ni_single, value=705.0,
#  'WBF_sgl_1_CALC_MEAN_TEMP_HE1_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_HE1_ni_single, value=1005.0,
#  'WBF_sgl_1_CALC_MEAN_TEMP_HE2_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_HE2_ni_single, value=1181.0,
#  'WBF_sgl_1_CALC_MEAN_TEMP_SOA_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_SOA_ni_single, value=1201.0,
#  'WBF_sgl_1_TARGET_MEAN_TEMP_CNV_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_CNV_ni_single, value=148.805755615234,
#  'WBF_sgl_1_TARGET_MEAN_TEMP_PHE_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_PHE_ni_single, value=779.681701660156,
#  'WBF_sgl_1_TARGET_MEAN_TEMP_HE1_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_HE1_ni_single, value=1055.44604492188,
#  'WBF_sgl_1_TARGET_MEAN_TEMP_HE2_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_HE2_ni_single, value=1185.98889160156,
#  'WBF_sgl_1_TARGET_MEAN_TEMP_SOA_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_SOA_ni_single, value=1193.0,
#  'WBF_sgl_1_CROSSING_TIME_CNV_ni_single': WBF_sgl_1_CROSSING_TIME_CNV_ni_single, value=0.0,
#  'WBF_sgl_1_CROSSING_TIME_PHE_ni_single': WBF_sgl_1_CROSSING_TIME_PHE_ni_single, value=0.0,
#  'WBF_sgl_1_CROSSING_TIME_HE1_ni_single': WBF_sgl_1_CROSSING_TIME_HE1_ni_single, value=0.0,
#  'WBF_sgl_1_CROSSING_TIME_HE2_ni_single': WBF_sgl_1_CROSSING_TIME_HE2_ni_single, value=0.0,
#  'WBF_sgl_1_CROSSING_TIME_SOA_ni_single': WBF_sgl_1_CROSSING_TIME_SOA_ni_single, value=0.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_HEAD_ni_single, value=1209.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_HEAD_ni_single, value=1194.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_HEAD_ni_single, value=1189.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_CENTR_ni_single, value=1215.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_CENTR_ni_single, value=1205.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_CENTR_ni_single, value=1204.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_TAIL_ni_single, value=1207.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_TAIL_ni_single, value=1194.0,
#  'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_TAIL_ni_single, value=1187.0,
#  'WBF_sgl_1_VALIDITY_ni_single': WBF_sgl_1_VALIDITY_ni_single, value=0.0,
#  'WBF_sgl_1_C_MODE_PERC_ni_single': WBF_sgl_1_C_MODE_PERC_ni_single, value=100.0,
#  'WBF_sgl_1_O_C_MODE_PERC_ni_single': WBF_sgl_1_O_C_MODE_PERC_ni_single, value=0.0,
#  'WBF_sgl_1_O_MODE_PERC_ni_single': WBF_sgl_1_O_MODE_PERC_ni_single, value=0.0,
#  'WBF_sgl_1_OXI_DEPTH_ni_single': WBF_sgl_1_OXI_DEPTH_ni_single, value=0.585743004205563,
#  'WBF_sgl_1_DEC_DEPTH_ni_single': WBF_sgl_1_DEC_DEPTH_ni_single, value=2.22830173681448,
#  'WBF_sgl_1_DELAY_ni_single': WBF_sgl_1_DELAY_ni_single, value=54.8511373,
#  'WBF_sgl_1_MAX_SKID_TEMP_ni_single': WBF_sgl_1_MAX_SKID_TEMP_ni_single, value=-60.0,
#  'WBF_sgl_1_X_POS_MAX_SKID_ni_single': WBF_sgl_1_X_POS_MAX_SKID_ni_single, value=719.0,
#  'WBF_sgl_1_MAX_DELTA_TEMP_ni_single': WBF_sgl_1_MAX_DELTA_TEMP_ni_single, value=79.0000205252711,
#  'WBF_sgl_1_DELTA_T_CROSS_ni_single': WBF_sgl_1_DELTA_T_CROSS_ni_single, value=10.0,
#  'WBF_sgl_1_DELTA_T_TOP_SURFACE_ni_single': WBF_sgl_1_DELTA_T_TOP_SURFACE_ni_single, value=12.9999024686874,
#  'WBF_sgl_1_CALC_T_DCHG_TOP_SURFACE_ni_single': WBF_sgl_1_CALC_T_DCHG_TOP_SURFACE_ni_single, value=1217.82513050629,
#  'WBF_sgl_1_MIN_RES_TIME_ni_single': WBF_sgl_1_MIN_RES_TIME_ni_single, value=10153.0,
#  'WBF_sgl_1_STEEL_CODE_ni_single': WBF_sgl_1_STEEL_CODE_ni_single, value=569.0,
#  'WBF_sgl_1_STEEL_MARK_ni_single': WBF_sgl_1_STEEL_MARK_ni_single, value=0.0,
#  'WBF_sgl_1_ROLLING_PROFILE_ni_single': WBF_sgl_1_ROLLING_PROFILE_ni_single, value=0.0,
#  'WBF_sgl_1_WEIGTH_IN_ni_single': WBF_sgl_1_WEIGTH_IN_ni_single, value=6690.0,
#  'WBF_sgl_1_WEIGHT_OUT_ni_single': WBF_sgl_1_WEIGHT_OUT_ni_single, value=6690.0,
#  'WBF_sgl_1_TIME_IN_ni_single': WBF_sgl_1_TIME_IN_ni_single, value=0.0,
#  'WBF_sgl_1_TIME_OUT_ni_single': WBF_sgl_1_TIME_OUT_ni_single, value=0.0,
#  'WBF_sgl_1_HEIGHT_IN_ni_single': WBF_sgl_1_HEIGHT_IN_ni_single, value=0.0,
#  'WBF_sgl_1_HEIGHT_OUT_ni_single': WBF_sgl_1_HEIGHT_OUT_ni_single, value=0.0,
#  'WBF_sgl_1_LENGTH_IN_ni_single': WBF_sgl_1_LENGTH_IN_ni_single, value=7883.0,
#  'WBF_sgl_1_LENGTH_OUT_ni_single': WBF_sgl_1_LENGTH_OUT_ni_single, value=7883.0,
#  'WBF_sgl_1_WIDTH_IN_ni_single': WBF_sgl_1_WIDTH_IN_ni_single, value=0.0,
#  'WBF_sgl_1_WIDTH_OUT_ni_single': WBF_sgl_1_WIDTH_OUT_ni_single, value=0.0,
#  'WBF_sgl_1_LENGTH_ORDERED_ni_single': WBF_sgl_1_LENGTH_ORDERED_ni_single, value=7.93,
#  'WBF_sgl_1_DENSITY_ni_single': WBF_sgl_1_DENSITY_ni_single, value=852.0,
#  'WBF_sgl_1_TEMPERATURE_IN_ni_single': WBF_sgl_1_TEMPERATURE_IN_ni_single, value=0.0,
#  'WBF_sgl_1_TEMPERATURE_OUT_ni_single': WBF_sgl_1_TEMPERATURE_OUT_ni_single, value=1.0,
#  'WBF_sgl_1_TEMPERATURE_MAX_ni_single': WBF_sgl_1_TEMPERATURE_MAX_ni_single, value=1187.0,
#  'WBF_sgl_1_TEMPERATURE_MIN_ni_single': WBF_sgl_1_TEMPERATURE_MIN_ni_single, value=1186.0,
#  'WBF_sgl_1_TEMPERATURE_AVG_ni_single': WBF_sgl_1_TEMPERATURE_AVG_ni_single, value=1187.0,
#  'WBF_sgl_1_WEIGHT_PROCESSED_ni_single': WBF_sgl_1_WEIGHT_PROCESSED_ni_single, value=6.7308,
#  'WBF_sgl_1_HEIGHT_PROCESSED_ni_single': WBF_sgl_1_HEIGHT_PROCESSED_ni_single, value=0.302,
#  'WBF_sgl_1_LENGTH_PROCESSED_ni_single': WBF_sgl_1_LENGTH_PROCESSED_ni_single, value=7.9,
#  'WBF_sgl_1_WIDTH_PROCESSED_ni_single': WBF_sgl_1_WIDTH_PROCESSED_ni_single, value=0.366,
#  'WBF_sgl_1_PZAG_ni_single': WBF_sgl_1_PZAG_ni_single, value=0.0,
#  'WBF_sgl_1_MELT_NUMBER_ni_single': WBF_sgl_1_MELT_NUMBER_ni_single, value=0.0,
#  'WBF_sgl_1_WEIGHT_ORDERED_ni_single': WBF_sgl_1_WEIGHT_ORDERED_ni_single, value=6.75636,
#  'WBF_sgl_1_MARKA_PROCESSED_ni_single': WBF_sgl_1_MARKA_PROCESSED_ni_single, value=0.0,
#  'WBF_sgl_1_STRAND_BILLET_NUMBER_ni_single': WBF_sgl_1_STRAND_BILLET_NUMBER_ni_single, value=1.0,
#  'WBF_sgl_1_STRAND_NUMBER_ni_single': WBF_sgl_1_STRAND_NUMBER_ni_single, value=1.0,
#  'WBF_sgl_1_CONTROL_ni_single': WBF_sgl_1_CONTROL_ni_single, value=1.0,
#  'WBF_sgl_1_STATUS_ni_single': WBF_sgl_1_STATUS_ni_single, value=3.0,
#  'WBF_sgl_1_ATTESTATED_ni_single': WBF_sgl_1_ATTESTATED_ni_single, value=0.0,
#  'WBF_sgl_1_PROFILE_VALID_ID_ni_single': WBF_sgl_1_PROFILE_VALID_ID_ni_single, value=1981.0,
#  'WBF_sgl_1_Z1_LV2_IN_percent_ni_single': WBF_sgl_1_Z1_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z2_LV2_IN_percent_ni_single': WBF_sgl_1_Z2_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z3_LV2_IN_percent_ni_single': WBF_sgl_1_Z3_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z4_LV2_IN_percent_ni_single': WBF_sgl_1_Z4_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z5_LV2_IN_percent_ni_single': WBF_sgl_1_Z5_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z6_LV2_IN_percent_ni_single': WBF_sgl_1_Z6_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z7_LV2_IN_percent_ni_single': WBF_sgl_1_Z7_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z8_LV2_IN_percent_ni_single': WBF_sgl_1_Z8_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z9_LV2_IN_percent_ni_single': WBF_sgl_1_Z9_LV2_IN_percent_ni_single, value=100.0,
#  'WBF_sgl_1_Z10_LV2_IN_percent_ni_single': WBF_sgl_1_Z10_LV2_IN_percent_ni_single, value=100.0}

# %%
file_path = 'testing/20240308000000_20240309000000_WBF.csv'
# Чтение файла с указанием кодировки ANSI
df = pd.read_csv(file_path, sep=';', encoding='ANSI')
forbidden_cols = ["billet_number", "CHARGING_TIME", "IS_DISCHARGED"]
for col in df.columns:
    if col not in forbidden_cols:
        # Если тип столбца - строка, заменяем запятые на точки и преобразуем в числовой тип
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.')
            df[col] = pd.to_numeric(df[col], errors='coerce')
df = df.fillna(0)
df
# Out:
#          PIECE_PK  FURNACE_FK billet_number        CHARGING_TIME  TOT_X_NODE  \
# 0    2.403071e+19           1    Л210444041  2024-03-07 19:36:25         100
# 1    2.403071e+19           1    Л210421011  2024-03-07 19:38:53         100
# 2    2.403071e+19           1    Л210422011  2024-03-07 19:41:17         100
# 3    2.403071e+19           1    Л210421051  2024-03-07 19:43:42         100
# 4    2.403071e+19           1    Л210422051  2024-03-07 19:45:58         100
# ..            ...         ...           ...                  ...         ...
# 489  2.403081e+19           1    Л210812020  2024-03-08 16:49:04         100
# 490  2.403081e+19           1    Л210813011  2024-03-08 16:51:04         100
# 491  2.403081e+19           1    Л210814011  2024-03-08 16:53:02         100
# 492  2.403081e+19           1    Л210813031  2024-03-08 16:55:02         100
# 493  2.403081e+19           1    Л210814031  2024-03-08 16:57:00         100
#
#      TOT_Y_NODE  TOT_Z_NODE   X_POS  X_COORD IS_DISCHARGED  ...  \
# 0             7           7  2714.0   6678.0             Y  ...
# 1             7           7   599.0   4540.5             Y  ...
# 2             7           7  2717.0   6666.5             Y  ...
# 3             7           7   598.0   4540.0             Y  ...
# 4             7           7  2718.0   6663.0             Y  ...
# ..          ...         ...     ...      ...           ...  ...
# 489           7           7   595.0   4538.5             Y  ...
# 490           7           7  2716.0   6670.0             Y  ...
# 491           7           7   548.0   4517.5             Y  ...
# 492           7           7  2710.0   6701.0             Y  ...
# 493           7           7   554.0   4520.0             Y  ...
#
#      Z1_LV2_IN_percent  Z2_LV2_IN_percent  Z3_LV2_IN_percent  \
# 0                100.0              100.0              100.0
# 1                100.0              100.0              100.0
# 2                100.0              100.0              100.0
# 3                100.0              100.0              100.0
# 4                100.0              100.0              100.0
# ..                 ...                ...                ...
# 489              100.0              100.0              100.0
# 490              100.0              100.0              100.0
# 491              100.0              100.0              100.0
# 492              100.0              100.0              100.0
# 493              100.0              100.0              100.0
#
#      Z4_LV2_IN_percent  Z5_LV2_IN_percent  Z6_LV2_IN_percent  \
# 0                100.0              100.0              100.0
# 1                100.0              100.0              100.0
# 2                100.0              100.0              100.0
# 3                100.0              100.0              100.0
# 4                100.0              100.0              100.0
# ..                 ...                ...                ...
# 489              100.0              100.0              100.0
# 490              100.0              100.0              100.0
# 491              100.0              100.0              100.0
# 492              100.0              100.0              100.0
# 493              100.0              100.0              100.0
#
#      Z7_LV2_IN_percent  Z8_LV2_IN_percent  Z9_LV2_IN_percent  \
# 0           100.000000         100.000000         100.000000
# 1           100.000000         100.000000         100.000000
# 2           100.000000         100.000000         100.000000
# 3           100.000000         100.000000         100.000000
# 4           100.000000         100.000000         100.000000
# ..                 ...                ...                ...
# 489          46.468058          46.464116          46.456725
# 490          45.746079          45.742149          45.734779
# 491          45.064495          45.060574          45.053221
# 492          44.328498          44.324590          44.317261
# 493          35.915445          35.912236          35.906220
#
#      Z10_LV2_IN_percent
# 0            100.000000
# 1            100.000000
# 2            100.000000
# 3            100.000000
# 4            100.000000
# ..                  ...
# 489           46.452045
# 490           45.730112
# 491           45.048564
# 492           44.312620
# 493           35.902410
#
# [494 rows x 106 columns]

# %%
data = df
data = data[data[settings.billet_column].apply(lambda x: x[:-1] in billet_id)]
data
# Out:
#        PIECE_PK  FURNACE_FK billet_number        CHARGING_TIME  TOT_X_NODE  \
# 1  2.403071e+19           1    Л210421011  2024-03-07 19:38:53         100
#
#    TOT_Y_NODE  TOT_Z_NODE  X_POS  X_COORD IS_DISCHARGED  ...  \
# 1           7           7  599.0   4540.5             Y  ...
#
#    Z1_LV2_IN_percent  Z2_LV2_IN_percent  Z3_LV2_IN_percent  Z4_LV2_IN_percent  \
# 1              100.0              100.0              100.0              100.0
#
#    Z5_LV2_IN_percent  Z6_LV2_IN_percent  Z7_LV2_IN_percent  Z8_LV2_IN_percent  \
# 1              100.0              100.0              100.0              100.0
#
#    Z9_LV2_IN_percent  Z10_LV2_IN_percent
# 1              100.0               100.0
#
# [1 rows x 106 columns]

# %%
df = df.fillna(0)
tmp = df.isna().sum().to_frame()
tmp[tmp[0] != 0]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
# Компоненты запуска процесса обработки файлов
PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# ID заготовки
billet_id = "Л210421011"

file_path = "testing/20240308000407_21046X404_IPSRNK_1_L.csv"
df = pd.read_csv(file_path, sep=';')
for col in df.columns:
    if col == "BilletPoints":
        df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce").fillna(0).astype(float)
    else:
        df[col] = pd.to_numeric(df[col].replace(",", "."), errors="coerce").fillna(0).astype(float)

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="LNK100",
    type="target",
    handler="BASE",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)

# Получение объекта BASEHandler
handler = handlers_factory.get_handler("BASE")

# Запуск обработки данных с помощью BASEHandler
seg_LNK100 = handler.process_pipeline(billet_id, data, settings)

# %%
# Компоненты запуска процесса обработки файлов
PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# Параметры для обработки
billet_id = "Л210421011"

file_path = 'testing/20240307170148_XX-Л210444041_WBF_1_T2.csv'
df = pd.read_csv(file_path, sep=';')
for col in df.drop("moment", axis=1).columns:
    df[col] = pd.to_numeric(df[col].str.replace(",", "."), errors="coerce")
df["moment"] = pd.to_datetime(df["moment"])

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="WBF_PIRO",
    type="feature",
    handler="WBFPIRO",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="billet_pirometer_files",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_PIRO_1": Segment(start_point=0, end_point="end", target_segments=["LNK100_1"])
        },
    forbidden_columns=["BEAM_VERT_ENC", "BEAM_HOR_ENC_POS", "DM_ENC_HOR_POS", "DML_VERT_POS", "DMR_VERT_POS"],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=['max', 'min','median','mean'],
    billet_column="moment",
    convert_columns={}
)

# Путь к файлу JSON до параметров окон для формирования дополнительных сегментов
file_path = "exploration/agregator/run/materials/wbf_piro_cutter_settings.json"
with open(file_path, "r") as file:
    piro_settings = json.load(file)

# Получение объекта WBFPIROHandler
handler = handlers_factory.get_handler("WBFPIRO")

# Запуск обработки данных с помощью WBFPIROHandler
seg_WBF_PIRO = handler.process_pipeline(billet_id, data, settings)
# Out:
# [153, 469, 752, 1152, 1706]
# [495, 773, 1172, 1596]
# [1892, 2067]
# [77, 1772, 1816, 2098, 2183, 2326]
# [100, 1772, 1820, 2095, 2186, 2322]
# [77, 100, 153, 469, 495, 752, 773, 1152, 1172, 1596, 1706, 1772, 1772, 1816, 1820, 1892, 2067, 2095, 2098, 2183, 2186, 2322, 2326]

# %%
# Компоненты запуска процесса обработки файлов
PATH_TO_MATERIALS=r"exploration\agregator\run\materials\*"

materials = Materials(
    {
        os.path.splitext(os.path.basename(path))[0]: path
        for path in glob(PATH_TO_MATERIALS)
    } if PATH_TO_MATERIALS else None
)

features_generator = FeaturesGenerator()
secondary_functions = SecondaryFunctions()
segments_aggregator = SegmentsAggregator()
filters = Filters()

# Фабрика сборки кастомных пайплайнов
handlers_factory = HandlersFactory(
    features_generator=features_generator,
    filters=filters,
    secondary_functions=secondary_functions,
    segments_aggregator=segments_aggregator,
    materials=materials
)

# Параметры для обработки
billet_id = "Л210421011"

file_path = 'testing/20240308000000_20240309000000_WBF.csv'
# Чтение файла с указанием кодировки ANSI
df = pd.read_csv(file_path, sep=';', encoding='ANSI')
forbidden_cols = ["billet_number", "CHARGING_TIME", "IS_DISCHARGED"]
for col in df.columns:
    if col not in forbidden_cols:
        # Если тип столбца - строка, заменяем запятые на точки и преобразуем в числовой тип
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace(',', '.')
            df[col] = pd.to_numeric(df[col], errors='coerce')
df = df.fillna(0)

data = df  # Ваш DataFrame

# Создание объекта SourceSettings
settings = SourceSettings(
    source="WBF_sgl",
    type="feature",
    handler="WBFSINGLE",
    rolling_number="1",
    encoding="ANSI",
    is_single=True,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_sgl_1": Segment(start_point=0, end_point=0, target_segments=["LNK100_1"])
        },
    forbidden_columns=[],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=[],
    billet_column="billet_number",
    convert_columns={}
)

# Получение объекта WBFSINGLEHandler
handler = handlers_factory.get_handler("WBFSINGLE")

# Запуск обработки данных с помощью WBFSINGLEHandler
seg_WBF_sgl = handler.process_pipeline(billet_id, data, settings)

# %%
all_aggregated_sources["WBF_PIRO"]
# Out:
# AggregatedSource(total_values=492, bad_values=0)

# %%
for segment_name, segment_values in all_aggregated_sources["WBF_PIRO"].items():
    print(segment_values)
# Out:
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min, value=1107.1539306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median, value=1183.767333984375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean, value=1165.8901766886754, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min, value=1083.94091796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median, value=1185.9375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean, value=1161.4180109833446, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min, value=1090.4803466796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median, value=1140.3935546875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean, value=1135.0946023830923}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max, value=1136.1689453125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_min, value=1126.21533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_median, value=1131.4525146484375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_mean, value=1131.4793543289136, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_max, value=1118.40283203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_min, value=1113.686279296875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_median, value=1116.52197265625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_mean, value=1116.3977636102622, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_max, value=1142.3900146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_min, value=1137.84716796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_median, value=1140.567138671875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_mean, value=1140.4376367033467}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_min, value=1135.2430419921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_median, value=1184.085693359375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_mean, value=1162.3072419502366, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_max, value=1186.71875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_min, value=1115.0751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_median, value=1156.5335693359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_mean, value=1150.460067963936, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_max, value=1143.2001953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_min, value=1125.9837646484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_median, value=1141.75341796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_mean, value=1138.0161837725573}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_max, value=1184.9248046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_min, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_median, value=1184.0567626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_mean, value=1184.006850244993, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_max, value=1187.1817626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_min, value=1185.7060546875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_median, value=1186.2557373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_mean, value=1186.3172580024548, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_max, value=1134.6353759765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_min, value=1126.4178466796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_median, value=1128.9930419921875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_mean, value=1129.414071936857}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_max, value=1185.7349853515625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_min, value=1183.6805419921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_median, value=1184.49072265625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_mean, value=1184.5315280123873, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_min, value=1186.0821533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_median, value=1186.8634033203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_mean, value=1186.8563802083333, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_min, value=1134.0567626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_median, value=1146.44091796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_mean, value=1145.5725044869089}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_min, value=1135.677001953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_median, value=1184.1435546875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_mean, value=1166.427486734151, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_max, value=1186.71875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_min, value=1115.219970703125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_median, value=1179.427001953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_mean, value=1156.4173465851813, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_max, value=1143.2001953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_min, value=1125.9837646484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_median, value=1141.3773193359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_mean, value=1136.8162719289035}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_max, value=1184.9248046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_min, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_median, value=1184.0567626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_mean, value=1184.0052233886718, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_max, value=1187.1817626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_min, value=1185.7060546875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_median, value=1186.2557373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_mean, value=1186.3234158325195, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_max, value=1134.6353759765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_min, value=1126.4178466796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_median, value=1129.2244873046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_mean, value=1129.7664715576173}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_max, value=1185.7349853515625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_min, value=1183.767333984375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_median, value=1184.5775146484375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_mean, value=1184.6189565142463, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_min, value=1186.0821533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_median, value=1186.892333984375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_mean, value=1186.8669933363972, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_min, value=1134.2882080078125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_median, value=1146.2384033203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_mean, value=1145.6241630284926}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_max, value=1184.2303466796875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_min, value=1179.7742919921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_median, value=1182.552978515625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_mean, value=1182.4062562422318, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_max, value=1186.1689453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_min, value=1183.0728759765625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_median, value=1185.0694580078125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_mean, value=1184.8582784479315, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_max, value=1147.829833984375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_min, value=1131.68408203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_median, value=1144.357666015625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_mean, value=1142.4507772272284}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_min, value=1126.0994873046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_median, value=1184.114501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_mean, value=1168.2261625325905, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_min, value=1112.38427734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_median, value=1186.2244873046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_mean, value=1164.2125706942577, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_min, value=1125.9837646484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_median, value=1141.2615966796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_mean, value=1139.2420100805894}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_max, value=1185.82177734375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_min, value=1184.49072265625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_median, value=1185.0694580078125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_mean, value=1185.1966634114583, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_max, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_min, value=1186.28466796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_median, value=1186.545166015625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_mean, value=1186.547802734375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_max, value=1148.1192626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_min, value=1147.6851806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_median, value=1147.9744873046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_mean, value=1147.9584906684029}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_max, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_min, value=1178.90625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_median, value=1182.8125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_mean, value=1182.5989226755742, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_max, value=1186.660888671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_min, value=1182.754638671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_median, value=1185.2430419921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_mean, value=1185.0904752374117, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_max, value=1148.4085693359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_min, value=1116.0885009765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_median, value=1145.138916015625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_mean, value=1141.6929698714941}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_max, value=1178.90625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_min, value=1175.376220703125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_median, value=1177.5028686523438, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_mean, value=1177.4805184297784, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_max, value=1183.0439453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_min, value=1182.4942626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_median, value=1182.754638671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_mean, value=1182.738370673601, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_max, value=1116.0885009765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_min, value=1105.526611328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_median, value=1107.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_mean, value=1108.456697685774}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_max, value=1182.8414306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_min, value=1110.6192626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_median, value=1123.6255493164062, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_mean, value=1133.4494518703884, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_max, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_min, value=1086.5740966796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_median, value=1090.0751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_mean, value=1114.073836432563, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_max, value=1106.4525146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_min, value=1094.7916259765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_median, value=1097.4537353515625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_mean, value=1098.970447116428}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_min, value=1126.0994873046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_median, value=1184.11474609375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_mean, value=1168.7975090651616, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_min, value=1113.5126953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_median, value=1186.2557373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_mean, value=1164.9185909218797, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_min, value=1125.9837646484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_median, value=1141.29052734375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_mean, value=1139.2836625121413}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_max, value=1185.82177734375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_min, value=1184.49072265625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_median, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_mean, value=1185.205172791773, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_max, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_min, value=1186.28466796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_median, value=1186.545166015625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_mean, value=1186.5363919005101, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_max, value=1148.1192626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_min, value=1147.6851806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_median, value=1147.9744873046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_mean, value=1147.9650405572386}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_max, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_min, value=1178.906494140625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_median, value=1182.8125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_mean, value=1182.599901282269, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_max, value=1186.660888671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_min, value=1182.7835693359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_median, value=1185.2430419921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_mean, value=1185.0964554496434, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_max, value=1148.4085693359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_min, value=1117.679443359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_median, value=1145.138916015625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_mean, value=1141.8680977199388}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_max, value=1178.906494140625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_min, value=1175.232666015625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_median, value=1177.5028686523438, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_mean, value=1177.4568335491679, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_max, value=1183.0439453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_min, value=1182.4942626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_median, value=1182.754638671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_mean, value=1182.7422618036685, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_max, value=1117.679443359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_min, value=1105.526611328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_median, value=1107.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_mean, value=1108.6751045558763}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_max, value=1182.8414306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_min, value=1110.6195068359375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_median, value=1123.6689453125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_mean, value=1133.1979205277714, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_max, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_min, value=1086.60302734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_median, value=1090.0751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_mean, value=1113.371253243328, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_max, value=1106.4525146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_min, value=1095.74658203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_median, value=1097.4537353515625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_mean, value=1098.932871129391}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_max, value=1127.34375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_min, value=1126.21533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_median, value=1126.6343994140625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_mean, value=1126.6951141357422, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_max, value=1113.5126953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_min, value=1112.38427734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_median, value=1112.8182373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_mean, value=1112.8845825195312, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_max, value=1136.545166015625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_min, value=1135.9664306640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_median, value=1136.226806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_mean, value=1136.2261199951172}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_max, value=1127.951416015625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_min, value=1126.0994873046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_median, value=1127.1267700195312, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_mean, value=1127.000897442853, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_max, value=1113.888916015625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_min, value=1113.5126953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_median, value=1113.686279296875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_mean, value=1113.7224460177952, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_max, value=1137.84716796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_min, value=1136.313720703125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_median, value=1136.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_mean, value=1136.8632111725983}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_max, value=1136.1689453125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_min, value=1126.21533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_median, value=1131.4525146484375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_mean, value=1131.4793543289136, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_max, value=1118.40283203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_min, value=1113.686279296875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_median, value=1116.52197265625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_mean, value=1116.3977636102622, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_max, value=1142.3900146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_min, value=1137.84716796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_median, value=1140.567138671875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_mean, value=1140.4376367033467}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_max, value=1135.879638671875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_min, value=1135.2430419921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_median, value=1135.66552734375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_mean, value=1135.6059886791088, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_max, value=1116.4351806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_min, value=1115.0751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_median, value=1115.5382080078125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_mean, value=1115.6646457248264, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_max, value=1142.62158203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_min, value=1141.8692626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_median, value=1142.3900146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_mean, value=1142.3375560619213}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_min, value=1135.677001953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_median, value=1184.3460693359375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_mean, value=1164.9985659103986, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_max, value=1186.71875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_min, value=1115.219970703125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_median, value=1177.77783203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_mean, value=1153.9656447772832, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_max, value=1143.2001953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_min, value=1125.9837646484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_median, value=1141.6666259765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_mean, value=1137.5811242391896}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_max, value=1184.4039306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_min, value=1183.7962646484375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_median, value=1183.9699096679688, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_mean, value=1184.0019420276988, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_max, value=1186.71875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_min, value=1186.37158203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_median, value=1186.5165405273438, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_mean, value=1186.5464588512075, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_max, value=1127.633056640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_min, value=1127.1412353515625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_median, value=1127.3726806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_mean, value=1127.4160711115057}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_max, value=1184.9248046875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_min, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_median, value=1184.0567626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_mean, value=1184.006580232319, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_max, value=1187.1817626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_min, value=1185.7060546875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_median, value=1186.2557373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_mean, value=1186.3043595163447, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_max, value=1134.6353759765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_min, value=1126.4178466796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_median, value=1129.1663818359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_mean, value=1129.5237645199425}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_max, value=1184.201416015625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_min, value=1183.6805419921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_median, value=1184.00341796875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_mean, value=1183.9762311662946, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_max, value=1186.83447265625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_min, value=1186.60302734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_median, value=1186.6898193359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_mean, value=1186.6815592447917, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_max, value=1134.6353759765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_min, value=1134.0567626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_median, value=1134.375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_mean, value=1134.3901657831102}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_max, value=1185.7349853515625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_min, value=1183.767333984375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_median, value=1184.5775146484375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_mean, value=1184.6189565142463, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_min, value=1186.0821533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_median, value=1186.892333984375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_mean, value=1186.8669933363972, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_min, value=1134.2882080078125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_median, value=1146.2384033203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_mean, value=1145.6241630284926}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_max, value=1185.214111328125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_min, value=1183.8541259765625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_median, value=1184.2882080078125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_mean, value=1184.2961491765202, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_max, value=1187.326416015625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_min, value=1186.37158203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_median, value=1186.83447265625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_mean, value=1186.8473835163288, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_max, value=1148.09033203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_min, value=1146.817138671875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_median, value=1147.395751953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_mean, value=1147.4068823462135}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_max, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_min, value=1184.2882080078125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_median, value=1184.80908203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_mean, value=1184.7717540228546, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_max, value=1187.094970703125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_min, value=1186.37158203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_median, value=1186.7244873046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_mean, value=1186.7323417094217, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_max, value=1148.4085693359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_min, value=1147.65625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_median, value=1148.032470703125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_mean, value=1148.0260556349115}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_max, value=1184.4925537109375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_min, value=1184.4925537109375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_median, value=1184.4925537109375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_mean, value=1184.4925537109375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_max, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_min, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_median, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_mean, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_max, value=1148.061279296875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_min, value=1148.061279296875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_median, value=1148.061279296875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_mean, value=1148.061279296875}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_max, value=1185.82177734375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_min, value=1184.49072265625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_median, value=1185.0694580078125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_mean, value=1185.1966634114583, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_max, value=1186.7476806640625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_min, value=1186.28466796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_median, value=1186.545166015625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_mean, value=1186.547802734375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_max, value=1148.1192626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_min, value=1147.6851806640625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_median, value=1147.9744873046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_mean, value=1147.9584906684029}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_max, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_min, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_median, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_mean, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_max, value=1186.429443359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_min, value=1186.4005126953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_median, value=1186.401611328125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_mean, value=1186.4123046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_max, value=1148.061279296875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_min, value=1147.9744873046875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_median, value=1148.057861328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_mean, value=1148.02587890625}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_max, value=1185.3009033203125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_min, value=1183.6226806640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_median, value=1184.375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_mean, value=1184.325439453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_max, value=1186.660888671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_min, value=1185.9375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_median, value=1186.458251953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_mean, value=1186.4430015250427, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_max, value=1148.4085693359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_min, value=1147.1064453125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_median, value=1147.65625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_mean, value=1147.7368030286816}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_max, value=1184.2303466796875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_min, value=1179.7742919921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_median, value=1182.552978515625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_mean, value=1182.4062562422318, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_max, value=1186.1689453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_min, value=1183.0728759765625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_median, value=1185.0694580078125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_mean, value=1184.8582784479315, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_max, value=1147.829833984375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_min, value=1131.68408203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_median, value=1144.357666015625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_mean, value=1142.4507772272284}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_max, value=1179.7742919921875, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_min, value=1178.906494140625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_median, value=1179.3692626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_mean, value=1179.388322501347, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_max, value=1183.3912353515625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_min, value=1182.7835693359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_median, value=1183.0728759765625, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_mean, value=1183.117570548222, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_max, value=1131.68408203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_min, value=1117.679443359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_median, value=1122.9166259765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_mean, value=1123.3883477572738}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_max, value=1178.906494140625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_min, value=1178.90625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_median, value=1178.90625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_mean, value=1178.9063110351562, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_max, value=1182.7835693359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_min, value=1182.754638671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_median, value=1182.7835693359375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_mean, value=1182.7763366699219, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_max, value=1117.679443359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_min, value=1116.0885009765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_median, value=1117.679443359375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_mean, value=1117.2817077636719}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_max, value=1178.90625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_min, value=1175.376220703125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_median, value=1177.5028686523438, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_mean, value=1177.4805184297784, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_max, value=1183.0439453125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_min, value=1182.4942626953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_median, value=1182.754638671875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_mean, value=1182.738370673601, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_max, value=1116.0885009765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_min, value=1105.526611328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_median, value=1107.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_mean, value=1108.456697685774}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_max, value=1175.376220703125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_min, value=1175.232666015625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_median, value=1175.376220703125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_mean, value=1175.34033203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_max, value=1182.8182373046875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_min, value=1182.8125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_median, value=1182.8125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_mean, value=1182.8139343261719, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_max, value=1105.9317626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_min, value=1105.879638671875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_median, value=1105.9317626953125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_mean, value=1105.9187316894531}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_max, value=1182.8414306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_min, value=1110.6195068359375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_median, value=1123.6689453125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_mean, value=1133.1979205277714, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_max, value=1182.9571533203125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_min, value=1086.60302734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_median, value=1090.0751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_mean, value=1113.371253243328, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_max, value=1106.4525146484375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_min, value=1095.74658203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_median, value=1097.4537353515625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_mean, value=1098.932871129391}
# {'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_max, value=1110.6195068359375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_min, value=1110.6192626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_median, value=1110.6192626953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_mean, value=1110.6193603515626, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_max, value=1086.60302734375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_min, value=1086.5740966796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_median, value=1086.5751953125, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_mean, value=1086.5861083984375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_max, value=1095.74658203125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_min, value=1094.7916259765625, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_median, value=1094.829833984375, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_mean, value=1095.1888916015625}

# %%
all_aggregated_sources["WBF_PIRO"].settings().segments["WBF_PIRO_1"]
# Out:
# Segment(start_point=0, end_point='end', target_segments=['LNK100_1'])

# %%
all_aggregated_sources["WBF_PIRO"].settings().segments["WBF_PIRO_1"].target_segments
# Out:
# ['LNK100_1']

# %%
all_aggregated_sources = {
    "LNK100": seg_LNK100,
    "WBF_PIRO": seg_WBF_PIRO,
    "WBF_sgl": seg_WBF_sgl
}

# %% [markdown]
# ### Matcher

# %%
class Matcher:

    def __init__(self, sources_settings: Dict[str, SourceSettings]):
        self.sources_settings = sources_settings
        self.target_name = [
            name for name, src in self.sources_settings.items()
            if src.type == "target"
        ][0]

    def match_features_to_target(
        self, all_aggregated_sources: Dict[str, AggregatedSourceDict]
    ) -> (Dict[str, AggregatedSegment], Dict[str, Dict[str, float]]):
        targets_segments = {
            seg_key: all_aggregated_sources[self.target_name][seg_key]
            for seg_key in self.sources_settings[self.target_name
                                                 ].segments.keys()
        }
        print(targets_segments)
        for source_name, source_values in all_aggregated_sources.items():
            if source_values.is_target():
                continue
            for segment_name, segment_values in source_values.items():
                segment_settings = source_values.settings(
                ).segments[segment_name]
                for target_name in segment_settings.target_segments:
                    targets_segments[target_name].append_value(
                        segment_values.values()
                    )
        targets_dict = self._create_dict_from_segments(targets_segments)
        return targets_segments, targets_dict

    @staticmethod
    def _create_dict_from_segments(
        targets_segments: Dict[str, AggregatedSegment]
    ) -> Dict[str, Dict[str, float]]:
        targets_dict = {}
        for target_segment, aggregated_values in targets_segments.items():
            targets_dict[target_segment] = {
                str(value.transcription):
                float(value.value) if value.value else None
                for value in aggregated_values.values()
            }
        return targets_dict

# %%
LNK100_settings = SourceSettings(
    source="LNK100",
    type="target",
    handler="BASE",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="ipsrnk",
    nested_folders="rail_points_files",
    filename_key="",
    interpolation_type="by_value",
    interpolation=103,
    segments={
            "LNK100_1": Segment(start_point=0, end_point=3, target_segments=[])
        },
    forbidden_columns=[],
    filtration_methods=["std"],
    secondary_features=["abs"],
    aggregation_methods=['max', 'min', 'median'],
    billet_column="BilletPoints",
    convert_columns={}
)

WBF_PIRO_settings = SourceSettings(
    source="WBF_PIRO",
    type="feature",
    handler="WBFPIRO",
    rolling_number="1",
    encoding="UTF-8",
    is_single=False,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="billet_pirometer_files",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_PIRO_1": Segment(start_point=0, end_point="end", target_segments=["LNK100_1"])
        },
    forbidden_columns=["BEAM_VERT_ENC", "BEAM_HOR_ENC_POS", "DM_ENC_HOR_POS", "DML_VERT_POS", "DMR_VERT_POS"],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=['max', 'min','median','mean'],
    billet_column="moment",
    convert_columns={}
)

WBF_sgl_settings = SourceSettings(
    source="WBF_sgl",
    type="feature",
    handler="WBFSINGLE",
    rolling_number="1",
    encoding="ANSI",
    is_single=True,
    main_folder="\\ZSMK-9684-001\Data\2023",
    key_folder="wbf",
    nested_folders="",
    filename_key="",
    interpolation_type="",
    interpolation="",
    segments={
            "WBF_sgl_1": Segment(start_point=0, end_point=0, target_segments=["LNK100_1"])
        },
    forbidden_columns=[],
    filtration_methods=[],
    secondary_features=[],
    aggregation_methods=[],
    billet_column="billet_number",
    convert_columns={}
)

sources_settings = {
    "LNK100": LNK100_settings,
    "WBF_PIRO": WBF_PIRO_settings,
    "WBF_sgl": WBF_sgl_settings
}

# %%
matcher = Matcher(sources_settings)

# %%
targets_segments, targets_dict = matcher.match_features_to_target(all_aggregated_sources)
# Out:
# {'LNK100_1': {'mill_LNK100_1_Hor1500_ni_0_3_max': mill_LNK100_1_Hor1500_ni_0_3_max, value=443.0, 'mill_LNK100_1_Hor1500_ni_0_3_min': mill_LNK100_1_Hor1500_ni_0_3_min, value=223.0, 'mill_LNK100_1_Hor1500_ni_0_3_median': mill_LNK100_1_Hor1500_ni_0_3_median, value=283.0, 'mill_LNK100_1_Hor2000_ni_0_3_max': mill_LNK100_1_Hor2000_ni_0_3_max, value=719.0, 'mill_LNK100_1_Hor2000_ni_0_3_min': mill_LNK100_1_Hor2000_ni_0_3_min, value=340.0, 'mill_LNK100_1_Hor2000_ni_0_3_median': mill_LNK100_1_Hor2000_ni_0_3_median, value=492.0, 'mill_LNK100_1_Torsion_ni_0_3_max': mill_LNK100_1_Torsion_ni_0_3_max, value=468.0, 'mill_LNK100_1_Torsion_ni_0_3_min': mill_LNK100_1_Torsion_ni_0_3_min, value=2.0, 'mill_LNK100_1_Torsion_ni_0_3_median': mill_LNK100_1_Torsion_ni_0_3_median, value=275.0, 'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max, value=195.0, 'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min, value=114.0, 'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median, value=139.0, 'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max, value=203.0, 'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min, value=158.0, 'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median, value=191.0, 'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max, value=253.0, 'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min, value=208.0, 'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median, value=217.0, 'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max, value=397.0, 'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min, value=240.0, 'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median, value=327.0, 'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max, value=238.0, 'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min, value=122.0, 'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median, value=150.0, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max, value=1187.239501953125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min, value=1107.1539306640625, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median, value=1183.767333984375, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean, value=1165.8901766886754, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max, value=1187.5867919921875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min, value=1083.94091796875, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median, value=1185.9375, 'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean, value=1161.4180109833446, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max, value=1148.495361328125, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min, value=1090.4803466796875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median, value=1140.3935546875, 'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean, value=1135.0946023830923, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max, value=1136.1689453125, 'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_ ...

# %%
targets_segments
# Out:
# {'LNK100_1': {'mill_LNK100_1_Hor1500_ni_0_3_max': mill_LNK100_1_Hor1500_ni_0_3_max, value=443.0,
#   'mill_LNK100_1_Hor1500_ni_0_3_min': mill_LNK100_1_Hor1500_ni_0_3_min, value=223.0,
#   'mill_LNK100_1_Hor1500_ni_0_3_median': mill_LNK100_1_Hor1500_ni_0_3_median, value=283.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_max': mill_LNK100_1_Hor2000_ni_0_3_max, value=719.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_min': mill_LNK100_1_Hor2000_ni_0_3_min, value=340.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_median': mill_LNK100_1_Hor2000_ni_0_3_median, value=492.0,
#   'mill_LNK100_1_Torsion_ni_0_3_max': mill_LNK100_1_Torsion_ni_0_3_max, value=468.0,
#   'mill_LNK100_1_Torsion_ni_0_3_min': mill_LNK100_1_Torsion_ni_0_3_min, value=2.0,
#   'mill_LNK100_1_Torsion_ni_0_3_median': mill_LNK100_1_Torsion_ni_0_3_median, value=275.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max, value=195.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min, value=114.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median, value=139.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max, value=203.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min, value=158.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median, value=191.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max, value=253.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min, value=208.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median, value=217.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max, value=397.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min, value=240.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median, value=327.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max, value=238.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min, value=122.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median': mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median, value=150.0,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min, value=1107.1539306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median, value=1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean, value=1165.8901766886754,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min, value=1083.94091796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median, value=1185.9375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean, value=1161.4180109833446,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min, value=1090.4803466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median, value=1140.3935546875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean, value=1135.0946023830923,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max, value=1136.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_min, value=1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_median, value=1131.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_mean, value=1131.4793543289136,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_max, value=1118.40283203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_min, value=1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_median, value=1116.52197265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_mean, value=1116.3977636102622,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_max, value=1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_min, value=1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_median, value=1140.567138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_mean, value=1140.4376367033467,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_min, value=1135.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_median, value=1184.085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_mean, value=1162.3072419502366,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_max, value=1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_min, value=1115.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_median, value=1156.5335693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_mean, value=1150.460067963936,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_max, value=1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_min, value=1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_median, value=1141.75341796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_mean, value=1138.0161837725573,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_max, value=1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_min, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_median, value=1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_mean, value=1184.006850244993,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_max, value=1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_min, value=1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_median, value=1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_mean, value=1186.3172580024548,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_max, value=1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_min, value=1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_median, value=1128.9930419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_mean, value=1129.414071936857,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_max, value=1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_min, value=1183.6805419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_median, value=1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_mean, value=1184.5315280123873,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_min, value=1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_median, value=1186.8634033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_mean, value=1186.8563802083333,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_min, value=1134.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_median, value=1146.44091796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_mean, value=1145.5725044869089,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_min, value=1135.677001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_median, value=1184.1435546875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_mean, value=1166.427486734151,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_max, value=1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_min, value=1115.219970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_median, value=1179.427001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_mean, value=1156.4173465851813,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_max, value=1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_min, value=1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_median, value=1141.3773193359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_mean, value=1136.8162719289035,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_max, value=1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_min, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_median, value=1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_mean, value=1184.0052233886718,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_max, value=1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_min, value=1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_median, value=1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_mean, value=1186.3234158325195,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_max, value=1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_min, value=1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_median, value=1129.2244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_mean, value=1129.7664715576173,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_max, value=1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_min, value=1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_median, value=1184.5775146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_mean, value=1184.6189565142463,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_min, value=1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_median, value=1186.892333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_mean, value=1186.8669933363972,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_min, value=1134.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_median, value=1146.2384033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_mean, value=1145.6241630284926,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_max, value=1184.2303466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_min, value=1179.7742919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_median, value=1182.552978515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_mean, value=1182.4062562422318,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_max, value=1186.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_min, value=1183.0728759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_median, value=1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_mean, value=1184.8582784479315,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_max, value=1147.829833984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_min, value=1131.68408203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_median, value=1144.357666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_mean, value=1142.4507772272284,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_min, value=1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_median, value=1184.114501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_mean, value=1168.2261625325905,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_min, value=1112.38427734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_median, value=1186.2244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_mean, value=1164.2125706942577,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_min, value=1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_median, value=1141.2615966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_mean, value=1139.2420100805894,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_max, value=1185.82177734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_min, value=1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_median, value=1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_mean, value=1185.1966634114583,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_max, value=1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_min, value=1186.28466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_median, value=1186.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_mean, value=1186.547802734375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_max, value=1148.1192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_min, value=1147.6851806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_median, value=1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_mean, value=1147.9584906684029,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_max, value=1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_min, value=1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_median, value=1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_mean, value=1182.5989226755742,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_max, value=1186.660888671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_min, value=1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_median, value=1185.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_mean, value=1185.0904752374117,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_max, value=1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_min, value=1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_median, value=1145.138916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_mean, value=1141.6929698714941,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_max, value=1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_min, value=1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_median, value=1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_mean, value=1177.4805184297784,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_max, value=1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_min, value=1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_median, value=1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_mean, value=1182.738370673601,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_max, value=1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_min, value=1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_median, value=1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_mean, value=1108.456697685774,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_max, value=1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_min, value=1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_median, value=1123.6255493164062,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_mean, value=1133.4494518703884,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_max, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_min, value=1086.5740966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_median, value=1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_mean, value=1114.073836432563,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_max, value=1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_min, value=1094.7916259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_median, value=1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_mean, value=1098.970447116428,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_min, value=1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_median, value=1184.11474609375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_mean, value=1168.7975090651616,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_min, value=1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_median, value=1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_mean, value=1164.9185909218797,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_min, value=1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_median, value=1141.29052734375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_mean, value=1139.2836625121413,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_max, value=1185.82177734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_min, value=1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_median, value=1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_mean, value=1185.205172791773,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_max, value=1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_min, value=1186.28466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_median, value=1186.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_mean, value=1186.5363919005101,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_max, value=1148.1192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_min, value=1147.6851806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_median, value=1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_mean, value=1147.9650405572386,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_max, value=1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_min, value=1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_median, value=1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_mean, value=1182.599901282269,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_max, value=1186.660888671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_min, value=1182.7835693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_median, value=1185.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_mean, value=1185.0964554496434,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_max, value=1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_min, value=1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_median, value=1145.138916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_mean, value=1141.8680977199388,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_max, value=1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_min, value=1175.232666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_median, value=1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_mean, value=1177.4568335491679,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_max, value=1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_min, value=1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_median, value=1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_mean, value=1182.7422618036685,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_max, value=1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_min, value=1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_median, value=1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_mean, value=1108.6751045558763,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_max, value=1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_min, value=1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_median, value=1123.6689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_mean, value=1133.1979205277714,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_max, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_min, value=1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_median, value=1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_mean, value=1113.371253243328,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_max, value=1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_min, value=1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_median, value=1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_mean, value=1098.932871129391,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_max, value=1127.34375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_min, value=1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_median, value=1126.6343994140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_mean, value=1126.6951141357422,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_max, value=1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_min, value=1112.38427734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_median, value=1112.8182373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_mean, value=1112.8845825195312,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_max, value=1136.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_min, value=1135.9664306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_median, value=1136.226806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_mean, value=1136.2261199951172,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_max, value=1127.951416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_min, value=1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_median, value=1127.1267700195312,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_mean, value=1127.000897442853,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_max, value=1113.888916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_min, value=1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_median, value=1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_mean, value=1113.7224460177952,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_max, value=1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_min, value=1136.313720703125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_median, value=1136.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_mean, value=1136.8632111725983,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_max, value=1136.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_min, value=1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_median, value=1131.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_mean, value=1131.4793543289136,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_max, value=1118.40283203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_min, value=1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_median, value=1116.52197265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_mean, value=1116.3977636102622,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_max, value=1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_min, value=1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_median, value=1140.567138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_mean, value=1140.4376367033467,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_max, value=1135.879638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_min, value=1135.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_median, value=1135.66552734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_mean, value=1135.6059886791088,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_max, value=1116.4351806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_min, value=1115.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_median, value=1115.5382080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_mean, value=1115.6646457248264,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_max, value=1142.62158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_min, value=1141.8692626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_median, value=1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_mean, value=1142.3375560619213,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_max, value=1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_min, value=1135.677001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_median, value=1184.3460693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_mean, value=1164.9985659103986,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_max, value=1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_min, value=1115.219970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_median, value=1177.77783203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_mean, value=1153.9656447772832,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_max, value=1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_min, value=1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_median, value=1141.6666259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_mean, value=1137.5811242391896,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_max, value=1184.4039306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_min, value=1183.7962646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_median, value=1183.9699096679688,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_mean, value=1184.0019420276988,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_max, value=1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_min, value=1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_median, value=1186.5165405273438,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_mean, value=1186.5464588512075,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_max, value=1127.633056640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_min, value=1127.1412353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_median, value=1127.3726806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_mean, value=1127.4160711115057,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_max, value=1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_min, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_median, value=1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_mean, value=1184.006580232319,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_max, value=1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_min, value=1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_median, value=1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_mean, value=1186.3043595163447,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_max, value=1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_min, value=1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_median, value=1129.1663818359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_mean, value=1129.5237645199425,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_max, value=1184.201416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_min, value=1183.6805419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_median, value=1184.00341796875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_mean, value=1183.9762311662946,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_max, value=1186.83447265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_min, value=1186.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_median, value=1186.6898193359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_mean, value=1186.6815592447917,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_max, value=1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_min, value=1134.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_median, value=1134.375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_mean, value=1134.3901657831102,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_max, value=1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_min, value=1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_median, value=1184.5775146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_mean, value=1184.6189565142463,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_max, value=1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_min, value=1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_median, value=1186.892333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_mean, value=1186.8669933363972,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_max, value=1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_min, value=1134.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_median, value=1146.2384033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_mean, value=1145.6241630284926,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_max, value=1185.214111328125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_min, value=1183.8541259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_median, value=1184.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_mean, value=1184.2961491765202,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_max, value=1187.326416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_min, value=1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_median, value=1186.83447265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_mean, value=1186.8473835163288,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_max, value=1148.09033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_min, value=1146.817138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_median, value=1147.395751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_mean, value=1147.4068823462135,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_max, value=1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_min, value=1184.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_median, value=1184.80908203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_mean, value=1184.7717540228546,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_max, value=1187.094970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_min, value=1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_median, value=1186.7244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_mean, value=1186.7323417094217,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_max, value=1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_min, value=1147.65625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_median, value=1148.032470703125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_mean, value=1148.0260556349115,
# ...
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_mean, value=1182.7763366699219,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_max, value=1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_min, value=1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_median, value=1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_mean, value=1117.2817077636719,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_max, value=1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_min, value=1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_median, value=1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_mean, value=1177.4805184297784,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_max, value=1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_min, value=1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_median, value=1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_mean, value=1182.738370673601,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_max, value=1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_min, value=1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_median, value=1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_mean, value=1108.456697685774,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_max, value=1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_min, value=1175.232666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_median, value=1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_mean, value=1175.34033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_max, value=1182.8182373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_min, value=1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_median, value=1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_mean, value=1182.8139343261719,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_max, value=1105.9317626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_min, value=1105.879638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_median, value=1105.9317626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_mean, value=1105.9187316894531,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_max, value=1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_min, value=1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_median, value=1123.6689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_mean, value=1133.1979205277714,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_max, value=1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_min, value=1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_median, value=1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_mean, value=1113.371253243328,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_max, value=1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_min, value=1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_median, value=1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_mean, value=1098.932871129391,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_max, value=1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_min, value=1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_median, value=1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_mean, value=1110.6193603515626,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_max, value=1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_min, value=1086.5740966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_median, value=1086.5751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_mean, value=1086.5861083984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_max': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_max, value=1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_min': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_min, value=1094.7916259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_median': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_median, value=1094.829833984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_mean': mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_mean, value=1095.1888916015625,
#   'WBF_sgl_1_PIECE_PK_ni_single': WBF_sgl_1_PIECE_PK_ni_single, value=2.4030712380000006e+19,
#   'WBF_sgl_1_FURNACE_FK_ni_single': WBF_sgl_1_FURNACE_FK_ni_single, value=1.0,
#   'WBF_sgl_1_CHARGING_TIME_ni_single': WBF_sgl_1_CHARGING_TIME_ni_single, value=None,
#   'WBF_sgl_1_TOT_X_NODE_ni_single': WBF_sgl_1_TOT_X_NODE_ni_single, value=100.0,
#   'WBF_sgl_1_TOT_Y_NODE_ni_single': WBF_sgl_1_TOT_Y_NODE_ni_single, value=7.0,
#   'WBF_sgl_1_TOT_Z_NODE_ni_single': WBF_sgl_1_TOT_Z_NODE_ni_single, value=7.0,
#   'WBF_sgl_1_X_POS_ni_single': WBF_sgl_1_X_POS_ni_single, value=599.0,
#   'WBF_sgl_1_X_COORD_ni_single': WBF_sgl_1_X_COORD_ni_single, value=4540.5,
#   'WBF_sgl_1_IS_DISCHARGED_ni_single': WBF_sgl_1_IS_DISCHARGED_ni_single, value=None,
#   'WBF_sgl_1_DISCHARGING_TIME_ni_single': WBF_sgl_1_DISCHARGING_TIME_ni_single, value=0.0,
#   'WBF_sgl_1_MARKA_ni_single': WBF_sgl_1_MARKA_ni_single, value=0.0,
#   'WBF_sgl_1_BISRA_ni_single': WBF_sgl_1_BISRA_ni_single, value=5.0,
#   'WBF_sgl_1_STRATEGY_ni_single': WBF_sgl_1_STRATEGY_ni_single, value=1.0,
#   'WBF_sgl_1_L_WBF_ni_single': WBF_sgl_1_L_WBF_ni_single, value=7883.0,
#   'WBF_sgl_1_H_WBF_ni_single': WBF_sgl_1_H_WBF_ni_single, value=300.0,
#   'WBF_sgl_1_W_WBF_ni_single': WBF_sgl_1_W_WBF_ni_single, value=366.0,
#   'WBF_sgl_1_WEIGHT_ni_single': WBF_sgl_1_WEIGHT_ni_single, value=6789.0,
#   'WBF_sgl_1_CHG_TEMP_ni_single': WBF_sgl_1_CHG_TEMP_ni_single, value=25.0,
#   'WBF_sgl_1_PLA_PACE_RATE_ni_single': WBF_sgl_1_PLA_PACE_RATE_ni_single, value=117.0,
#   'WBF_sgl_1_CUR_PACE_RATE_ni_single': WBF_sgl_1_CUR_PACE_RATE_ni_single, value=147.0,
#   'WBF_sgl_1_TARGET_TEMP_ni_single': WBF_sgl_1_TARGET_TEMP_ni_single, value=1220.0,
#   'WBF_sgl_1_TARGET_TEMP_Cor_ni_single': WBF_sgl_1_TARGET_TEMP_Cor_ni_single, value=-57.0,
#   'WBF_sgl_1_DCHG_TARGET_TEMP_PDI_ni_single': WBF_sgl_1_DCHG_TARGET_TEMP_PDI_ni_single, value=1220.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_CNV_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_CNV_ni_single, value=108.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_PHE_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_PHE_ni_single, value=705.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_HE1_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_HE1_ni_single, value=1005.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_HE2_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_HE2_ni_single, value=1181.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_SOA_ni_single': WBF_sgl_1_CALC_MEAN_TEMP_SOA_ni_single, value=1201.0,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_CNV_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_CNV_ni_single, value=148.805755615234,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_PHE_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_PHE_ni_single, value=779.681701660156,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_HE1_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_HE1_ni_single, value=1055.44604492188,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_HE2_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_HE2_ni_single, value=1185.98889160156,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_SOA_ni_single': WBF_sgl_1_TARGET_MEAN_TEMP_SOA_ni_single, value=1193.0,
#   'WBF_sgl_1_CROSSING_TIME_CNV_ni_single': WBF_sgl_1_CROSSING_TIME_CNV_ni_single, value=0.0,
#   'WBF_sgl_1_CROSSING_TIME_PHE_ni_single': WBF_sgl_1_CROSSING_TIME_PHE_ni_single, value=0.0,
#   'WBF_sgl_1_CROSSING_TIME_HE1_ni_single': WBF_sgl_1_CROSSING_TIME_HE1_ni_single, value=0.0,
#   'WBF_sgl_1_CROSSING_TIME_HE2_ni_single': WBF_sgl_1_CROSSING_TIME_HE2_ni_single, value=0.0,
#   'WBF_sgl_1_CROSSING_TIME_SOA_ni_single': WBF_sgl_1_CROSSING_TIME_SOA_ni_single, value=0.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_HEAD_ni_single, value=1209.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_HEAD_ni_single, value=1194.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_HEAD_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_HEAD_ni_single, value=1189.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_CENTR_ni_single, value=1215.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_CENTR_ni_single, value=1205.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_CENTR_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_CENTR_ni_single, value=1204.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_TAIL_ni_single, value=1207.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_TAIL_ni_single, value=1194.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_TAIL_ni_single': WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_TAIL_ni_single, value=1187.0,
#   'WBF_sgl_1_VALIDITY_ni_single': WBF_sgl_1_VALIDITY_ni_single, value=0.0,
#   'WBF_sgl_1_C_MODE_PERC_ni_single': WBF_sgl_1_C_MODE_PERC_ni_single, value=100.0,
#   'WBF_sgl_1_O_C_MODE_PERC_ni_single': WBF_sgl_1_O_C_MODE_PERC_ni_single, value=0.0,
#   'WBF_sgl_1_O_MODE_PERC_ni_single': WBF_sgl_1_O_MODE_PERC_ni_single, value=0.0,
#   'WBF_sgl_1_OXI_DEPTH_ni_single': WBF_sgl_1_OXI_DEPTH_ni_single, value=0.585743004205563,
#   'WBF_sgl_1_DEC_DEPTH_ni_single': WBF_sgl_1_DEC_DEPTH_ni_single, value=2.22830173681448,
#   'WBF_sgl_1_DELAY_ni_single': WBF_sgl_1_DELAY_ni_single, value=54.8511373,
#   'WBF_sgl_1_MAX_SKID_TEMP_ni_single': WBF_sgl_1_MAX_SKID_TEMP_ni_single, value=-60.0,
#   'WBF_sgl_1_X_POS_MAX_SKID_ni_single': WBF_sgl_1_X_POS_MAX_SKID_ni_single, value=719.0,
#   'WBF_sgl_1_MAX_DELTA_TEMP_ni_single': WBF_sgl_1_MAX_DELTA_TEMP_ni_single, value=79.0000205252711,
#   'WBF_sgl_1_DELTA_T_CROSS_ni_single': WBF_sgl_1_DELTA_T_CROSS_ni_single, value=10.0,
#   'WBF_sgl_1_DELTA_T_TOP_SURFACE_ni_single': WBF_sgl_1_DELTA_T_TOP_SURFACE_ni_single, value=12.9999024686874,
#   'WBF_sgl_1_CALC_T_DCHG_TOP_SURFACE_ni_single': WBF_sgl_1_CALC_T_DCHG_TOP_SURFACE_ni_single, value=1217.82513050629,
#   'WBF_sgl_1_MIN_RES_TIME_ni_single': WBF_sgl_1_MIN_RES_TIME_ni_single, value=10153.0,
#   'WBF_sgl_1_STEEL_CODE_ni_single': WBF_sgl_1_STEEL_CODE_ni_single, value=569.0,
#   'WBF_sgl_1_STEEL_MARK_ni_single': WBF_sgl_1_STEEL_MARK_ni_single, value=0.0,
#   'WBF_sgl_1_ROLLING_PROFILE_ni_single': WBF_sgl_1_ROLLING_PROFILE_ni_single, value=0.0,
#   'WBF_sgl_1_WEIGTH_IN_ni_single': WBF_sgl_1_WEIGTH_IN_ni_single, value=6690.0,
#   'WBF_sgl_1_WEIGHT_OUT_ni_single': WBF_sgl_1_WEIGHT_OUT_ni_single, value=6690.0,
#   'WBF_sgl_1_TIME_IN_ni_single': WBF_sgl_1_TIME_IN_ni_single, value=0.0,
#   'WBF_sgl_1_TIME_OUT_ni_single': WBF_sgl_1_TIME_OUT_ni_single, value=0.0,
#   'WBF_sgl_1_HEIGHT_IN_ni_single': WBF_sgl_1_HEIGHT_IN_ni_single, value=0.0,
#   'WBF_sgl_1_HEIGHT_OUT_ni_single': WBF_sgl_1_HEIGHT_OUT_ni_single, value=0.0,
#   'WBF_sgl_1_LENGTH_IN_ni_single': WBF_sgl_1_LENGTH_IN_ni_single, value=7883.0,
#   'WBF_sgl_1_LENGTH_OUT_ni_single': WBF_sgl_1_LENGTH_OUT_ni_single, value=7883.0,
#   'WBF_sgl_1_WIDTH_IN_ni_single': WBF_sgl_1_WIDTH_IN_ni_single, value=0.0,
#   'WBF_sgl_1_WIDTH_OUT_ni_single': WBF_sgl_1_WIDTH_OUT_ni_single, value=0.0,
#   'WBF_sgl_1_LENGTH_ORDERED_ni_single': WBF_sgl_1_LENGTH_ORDERED_ni_single, value=7.93,
#   'WBF_sgl_1_DENSITY_ni_single': WBF_sgl_1_DENSITY_ni_single, value=852.0,
#   'WBF_sgl_1_TEMPERATURE_IN_ni_single': WBF_sgl_1_TEMPERATURE_IN_ni_single, value=0.0,
#   'WBF_sgl_1_TEMPERATURE_OUT_ni_single': WBF_sgl_1_TEMPERATURE_OUT_ni_single, value=1.0,
#   'WBF_sgl_1_TEMPERATURE_MAX_ni_single': WBF_sgl_1_TEMPERATURE_MAX_ni_single, value=1187.0,
#   'WBF_sgl_1_TEMPERATURE_MIN_ni_single': WBF_sgl_1_TEMPERATURE_MIN_ni_single, value=1186.0,
#   'WBF_sgl_1_TEMPERATURE_AVG_ni_single': WBF_sgl_1_TEMPERATURE_AVG_ni_single, value=1187.0,
#   'WBF_sgl_1_WEIGHT_PROCESSED_ni_single': WBF_sgl_1_WEIGHT_PROCESSED_ni_single, value=6.7308,
#   'WBF_sgl_1_HEIGHT_PROCESSED_ni_single': WBF_sgl_1_HEIGHT_PROCESSED_ni_single, value=0.302,
#   'WBF_sgl_1_LENGTH_PROCESSED_ni_single': WBF_sgl_1_LENGTH_PROCESSED_ni_single, value=7.9,
#   'WBF_sgl_1_WIDTH_PROCESSED_ni_single': WBF_sgl_1_WIDTH_PROCESSED_ni_single, value=0.366,
#   'WBF_sgl_1_PZAG_ni_single': WBF_sgl_1_PZAG_ni_single, value=0.0,
#   'WBF_sgl_1_MELT_NUMBER_ni_single': WBF_sgl_1_MELT_NUMBER_ni_single, value=0.0,
#   'WBF_sgl_1_WEIGHT_ORDERED_ni_single': WBF_sgl_1_WEIGHT_ORDERED_ni_single, value=6.75636,
#   'WBF_sgl_1_MARKA_PROCESSED_ni_single': WBF_sgl_1_MARKA_PROCESSED_ni_single, value=0.0,
#   'WBF_sgl_1_STRAND_BILLET_NUMBER_ni_single': WBF_sgl_1_STRAND_BILLET_NUMBER_ni_single, value=1.0,
#   'WBF_sgl_1_STRAND_NUMBER_ni_single': WBF_sgl_1_STRAND_NUMBER_ni_single, value=1.0,
#   'WBF_sgl_1_CONTROL_ni_single': WBF_sgl_1_CONTROL_ni_single, value=1.0,
#   'WBF_sgl_1_STATUS_ni_single': WBF_sgl_1_STATUS_ni_single, value=3.0,
#   'WBF_sgl_1_ATTESTATED_ni_single': WBF_sgl_1_ATTESTATED_ni_single, value=0.0,
#   'WBF_sgl_1_PROFILE_VALID_ID_ni_single': WBF_sgl_1_PROFILE_VALID_ID_ni_single, value=1981.0,
#   'WBF_sgl_1_Z1_LV2_IN_percent_ni_single': WBF_sgl_1_Z1_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z2_LV2_IN_percent_ni_single': WBF_sgl_1_Z2_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z3_LV2_IN_percent_ni_single': WBF_sgl_1_Z3_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z4_LV2_IN_percent_ni_single': WBF_sgl_1_Z4_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z5_LV2_IN_percent_ni_single': WBF_sgl_1_Z5_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z6_LV2_IN_percent_ni_single': WBF_sgl_1_Z6_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z7_LV2_IN_percent_ni_single': WBF_sgl_1_Z7_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z8_LV2_IN_percent_ni_single': WBF_sgl_1_Z8_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z9_LV2_IN_percent_ni_single': WBF_sgl_1_Z9_LV2_IN_percent_ni_single, value=100.0,
#   'WBF_sgl_1_Z10_LV2_IN_percent_ni_single': WBF_sgl_1_Z10_LV2_IN_percent_ni_single, value=100.0}}

# %%
targets_dict.keys
# Out:
# {'LNK100_1': {'mill_LNK100_1_Hor1500_ni_0_3_max': 443.0,
#   'mill_LNK100_1_Hor1500_ni_0_3_min': 223.0,
#   'mill_LNK100_1_Hor1500_ni_0_3_median': 283.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_max': 719.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_min': 340.0,
#   'mill_LNK100_1_Hor2000_ni_0_3_median': 492.0,
#   'mill_LNK100_1_Torsion_ni_0_3_max': 468.0,
#   'mill_LNK100_1_Torsion_ni_0_3_min': 2.0,
#   'mill_LNK100_1_Torsion_ni_0_3_median': 275.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_max': 195.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_min': 114.0,
#   'mill_LNK100_1_Vert1000_[i_0.0_103.0]_0_3_median': 139.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_max': 203.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_min': 158.0,
#   'mill_LNK100_1_Vert1500_[i_0.0_103.0]_0_3_median': 191.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_max': 253.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_min': 208.0,
#   'mill_LNK100_1_Vert2000_[i_0.0_103.0]_0_3_median': 217.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_max': 397.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_min': 240.0,
#   'mill_LNK100_1_Vert3000_[i_0.0_103.0]_0_3_median': 327.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_max': 238.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_min': 122.0,
#   'mill_LNK100_1_Hor1000_[i_0.0_103.0]_0_3_median': 150.0,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_min': 1107.1539306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_median': 1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_WBF_PIRO_1_mean': 1165.8901766886754,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_min': 1083.94091796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_median': 1185.9375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_WBF_PIRO_1_mean': 1161.4180109833446,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_min': 1090.4803466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_median': 1140.3935546875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_WBF_PIRO_1_mean': 1135.0946023830923,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_max': 1136.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_min': 1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_median': 1131.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_0_mean': 1131.4793543289136,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_max': 1118.40283203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_min': 1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_median': 1116.52197265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_0_mean': 1116.3977636102622,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_max': 1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_min': 1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_median': 1140.567138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_0_mean': 1140.4376367033467,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_min': 1135.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_median': 1184.085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_1_mean': 1162.3072419502366,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_max': 1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_min': 1115.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_median': 1156.5335693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_1_mean': 1150.460067963936,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_max': 1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_min': 1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_median': 1141.75341796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_1_mean': 1138.0161837725573,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_max': 1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_min': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_median': 1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_2_mean': 1184.006850244993,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_max': 1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_min': 1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_median': 1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_2_mean': 1186.3172580024548,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_max': 1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_min': 1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_median': 1128.9930419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_2_mean': 1129.414071936857,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_max': 1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_min': 1183.6805419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_median': 1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_VERT_ENC_3_mean': 1184.5315280123873,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_min': 1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_median': 1186.8634033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_VERT_ENC_3_mean': 1186.8563802083333,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_min': 1134.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_median': 1146.44091796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_VERT_ENC_3_mean': 1145.5725044869089,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_min': 1135.677001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_median': 1184.1435546875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_0_mean': 1166.427486734151,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_max': 1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_min': 1115.219970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_median': 1179.427001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_0_mean': 1156.4173465851813,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_max': 1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_min': 1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_median': 1141.3773193359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_0_mean': 1136.8162719289035,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_max': 1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_min': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_median': 1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_1_mean': 1184.0052233886718,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_max': 1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_min': 1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_median': 1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_1_mean': 1186.3234158325195,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_max': 1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_min': 1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_median': 1129.2244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_1_mean': 1129.7664715576173,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_max': 1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_min': 1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_median': 1184.5775146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_BEAM_HOR_ENC_POS_2_mean': 1184.6189565142463,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_min': 1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_median': 1186.892333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_BEAM_HOR_ENC_POS_2_mean': 1186.8669933363972,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_min': 1134.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_median': 1146.2384033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_BEAM_HOR_ENC_POS_2_mean': 1145.6241630284926,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_max': 1184.2303466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_min': 1179.7742919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_median': 1182.552978515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DM_ENC_HOR_POS_0_mean': 1182.4062562422318,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_max': 1186.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_min': 1183.0728759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_median': 1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DM_ENC_HOR_POS_0_mean': 1184.8582784479315,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_max': 1147.829833984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_min': 1131.68408203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_median': 1144.357666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DM_ENC_HOR_POS_0_mean': 1142.4507772272284,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_min': 1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_median': 1184.114501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_0_mean': 1168.2261625325905,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_min': 1112.38427734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_median': 1186.2244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_0_mean': 1164.2125706942577,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_min': 1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_median': 1141.2615966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_0_mean': 1139.2420100805894,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_max': 1185.82177734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_min': 1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_median': 1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_1_mean': 1185.1966634114583,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_max': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_min': 1186.28466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_median': 1186.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_1_mean': 1186.547802734375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_max': 1148.1192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_min': 1147.6851806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_median': 1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_1_mean': 1147.9584906684029,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_max': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_min': 1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_median': 1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_2_mean': 1182.5989226755742,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_max': 1186.660888671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_min': 1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_median': 1185.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_2_mean': 1185.0904752374117,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_max': 1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_min': 1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_median': 1145.138916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_2_mean': 1141.6929698714941,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_max': 1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_min': 1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_median': 1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_3_mean': 1177.4805184297784,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_max': 1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_min': 1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_median': 1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_3_mean': 1182.738370673601,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_max': 1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_min': 1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_median': 1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_3_mean': 1108.456697685774,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_max': 1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_min': 1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_median': 1123.6255493164062,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DML_VERT_POS_4_mean': 1133.4494518703884,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_max': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_min': 1086.5740966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_median': 1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DML_VERT_POS_4_mean': 1114.073836432563,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_max': 1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_min': 1094.7916259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_median': 1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DML_VERT_POS_4_mean': 1098.970447116428,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_min': 1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_median': 1184.11474609375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_0_mean': 1168.7975090651616,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_min': 1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_median': 1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_0_mean': 1164.9185909218797,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_min': 1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_median': 1141.29052734375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_0_mean': 1139.2836625121413,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_max': 1185.82177734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_min': 1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_median': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_1_mean': 1185.205172791773,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_max': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_min': 1186.28466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_median': 1186.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_1_mean': 1186.5363919005101,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_max': 1148.1192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_min': 1147.6851806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_median': 1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_1_mean': 1147.9650405572386,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_max': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_min': 1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_median': 1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_2_mean': 1182.599901282269,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_max': 1186.660888671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_min': 1182.7835693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_median': 1185.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_2_mean': 1185.0964554496434,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_max': 1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_min': 1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_median': 1145.138916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_2_mean': 1141.8680977199388,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_max': 1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_min': 1175.232666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_median': 1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_3_mean': 1177.4568335491679,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_max': 1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_min': 1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_median': 1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_3_mean': 1182.7422618036685,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_max': 1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_min': 1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_median': 1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_3_mean': 1108.6751045558763,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_max': 1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_min': 1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_median': 1123.6689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_DMR_VERT_POS_4_mean': 1133.1979205277714,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_max': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_min': 1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_median': 1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_DMR_VERT_POS_4_mean': 1113.371253243328,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_max': 1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_min': 1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_median': 1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_DMR_VERT_POS_4_mean': 1098.932871129391,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_max': 1127.34375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_min': 1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_median': 1126.6343994140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_0_mean': 1126.6951141357422,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_max': 1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_min': 1112.38427734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_median': 1112.8182373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_0_mean': 1112.8845825195312,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_max': 1136.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_min': 1135.9664306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_median': 1136.226806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_0_mean': 1136.2261199951172,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_max': 1127.951416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_min': 1126.0994873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_median': 1127.1267700195312,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_1_mean': 1127.000897442853,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_max': 1113.888916015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_min': 1113.5126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_median': 1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_1_mean': 1113.7224460177952,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_max': 1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_min': 1136.313720703125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_median': 1136.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_1_mean': 1136.8632111725983,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_max': 1136.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_min': 1126.21533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_median': 1131.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_2_mean': 1131.4793543289136,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_max': 1118.40283203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_min': 1113.686279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_median': 1116.52197265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_2_mean': 1116.3977636102622,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_max': 1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_min': 1137.84716796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_median': 1140.567138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_2_mean': 1140.4376367033467,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_max': 1135.879638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_min': 1135.2430419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_median': 1135.66552734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_3_mean': 1135.6059886791088,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_max': 1116.4351806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_min': 1115.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_median': 1115.5382080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_3_mean': 1115.6646457248264,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_max': 1142.62158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_min': 1141.8692626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_median': 1142.3900146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_3_mean': 1142.3375560619213,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_max': 1187.239501953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_min': 1135.677001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_median': 1184.3460693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_4_mean': 1164.9985659103986,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_max': 1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_min': 1115.219970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_median': 1177.77783203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_4_mean': 1153.9656447772832,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_max': 1143.2001953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_min': 1125.9837646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_median': 1141.6666259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_4_mean': 1137.5811242391896,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_max': 1184.4039306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_min': 1183.7962646484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_median': 1183.9699096679688,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_5_mean': 1184.0019420276988,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_max': 1186.71875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_min': 1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_median': 1186.5165405273438,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_5_mean': 1186.5464588512075,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_max': 1127.633056640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_min': 1127.1412353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_median': 1127.3726806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_5_mean': 1127.4160711115057,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_max': 1184.9248046875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_min': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_median': 1184.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_6_mean': 1184.006580232319,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_max': 1187.1817626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_min': 1185.7060546875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_median': 1186.2557373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_6_mean': 1186.3043595163447,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_max': 1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_min': 1126.4178466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_median': 1129.1663818359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_6_mean': 1129.5237645199425,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_max': 1184.201416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_min': 1183.6805419921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_median': 1184.00341796875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_7_mean': 1183.9762311662946,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_max': 1186.83447265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_min': 1186.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_median': 1186.6898193359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_7_mean': 1186.6815592447917,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_max': 1134.6353759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_min': 1134.0567626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_median': 1134.375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_7_mean': 1134.3901657831102,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_max': 1185.7349853515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_min': 1183.767333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_median': 1184.5775146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_8_mean': 1184.6189565142463,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_max': 1187.5867919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_min': 1186.0821533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_median': 1186.892333984375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_8_mean': 1186.8669933363972,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_max': 1148.495361328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_min': 1134.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_median': 1146.2384033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_8_mean': 1145.6241630284926,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_max': 1185.214111328125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_min': 1183.8541259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_median': 1184.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_9_mean': 1184.2961491765202,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_max': 1187.326416015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_min': 1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_median': 1186.83447265625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_9_mean': 1186.8473835163288,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_max': 1148.09033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_min': 1146.817138671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_median': 1147.395751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_9_mean': 1147.4068823462135,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_max': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_min': 1184.2882080078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_median': 1184.80908203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_10_mean': 1184.7717540228546,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_max': 1187.094970703125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_min': 1186.37158203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_median': 1186.7244873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_10_mean': 1186.7323417094217,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_max': 1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_min': 1147.65625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_median': 1148.032470703125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_10_mean': 1148.0260556349115,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_max': 1184.4925537109375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_min': 1184.4925537109375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_median': 1184.4925537109375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_11_mean': 1184.4925537109375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_max': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_min': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_median': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_11_mean': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_max': 1148.061279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_min': 1148.061279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_median': 1148.061279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_11_mean': 1148.061279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_max': 1185.82177734375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_min': 1184.49072265625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_median': 1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_12_mean': 1185.1966634114583,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_max': 1186.7476806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_min': 1186.28466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_median': 1186.545166015625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_12_mean': 1186.547802734375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_max': 1148.1192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_min': 1147.6851806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_median': 1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_12_mean': 1147.9584906684029,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_max': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_min': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_median': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_13_mean': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_max': 1186.429443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_min': 1186.4005126953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_median': 1186.401611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_13_mean': 1186.4123046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_max': 1148.061279296875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_min': 1147.9744873046875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_median': 1148.057861328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_13_mean': 1148.02587890625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_max': 1185.3009033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_min': 1183.6226806640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_median': 1184.375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_14_mean': 1184.325439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_max': 1186.660888671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_min': 1185.9375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_median': 1186.458251953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_14_mean': 1186.4430015250427,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_max': 1148.4085693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_min': 1147.1064453125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_median': 1147.65625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_14_mean': 1147.7368030286816,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_max': 1184.2303466796875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_min': 1179.7742919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_median': 1182.552978515625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_15_mean': 1182.4062562422318,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_max': 1186.1689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_min': 1183.0728759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_median': 1185.0694580078125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_15_mean': 1184.8582784479315,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_max': 1147.829833984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_min': 1131.68408203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_median': 1144.357666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_15_mean': 1142.4507772272284,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_max': 1179.7742919921875,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_min': 1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_median': 1179.3692626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_16_mean': 1179.388322501347,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_max': 1183.3912353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_min': 1182.7835693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_median': 1183.0728759765625,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_16_mean': 1183.117570548222,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_max': 1131.68408203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_min': 1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_median': 1122.9166259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_16_mean': 1123.3883477572738,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_max': 1178.906494140625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_min': 1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_median': 1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_17_mean': 1178.9063110351562,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_max': 1182.7835693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_min': 1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_median': 1182.7835693359375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_17_mean': 1182.7763366699219,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_max': 1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_min': 1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_median': 1117.679443359375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_17_mean': 1117.2817077636719,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_max': 1178.90625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_min': 1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_median': 1177.5028686523438,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_18_mean': 1177.4805184297784,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_max': 1183.0439453125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_min': 1182.4942626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_median': 1182.754638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_18_mean': 1182.738370673601,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_max': 1116.0885009765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_min': 1105.526611328125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_median': 1107.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_18_mean': 1108.456697685774,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_max': 1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_min': 1175.232666015625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_median': 1175.376220703125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_19_mean': 1175.34033203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_max': 1182.8182373046875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_min': 1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_median': 1182.8125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_19_mean': 1182.8139343261719,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_max': 1105.9317626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_min': 1105.879638671875,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_median': 1105.9317626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_19_mean': 1105.9187316894531,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_max': 1182.8414306640625,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_min': 1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_median': 1123.6689453125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_20_mean': 1133.1979205277714,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_max': 1182.9571533203125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_min': 1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_median': 1090.0751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_20_mean': 1113.371253243328,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_max': 1106.4525146484375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_min': 1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_median': 1097.4537353515625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_20_mean': 1098.932871129391,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_max': 1110.6195068359375,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_min': 1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_median': 1110.6192626953125,
#   'mill_WBF_PIRO_1_TEMP_PIR3_ni_ALL_PTS_21_mean': 1110.6193603515626,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_max': 1086.60302734375,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_min': 1086.5740966796875,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_median': 1086.5751953125,
#   'mill_WBF_PIRO_1_TEMP_PIR1_ni_ALL_PTS_21_mean': 1086.5861083984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_max': 1095.74658203125,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_min': 1094.7916259765625,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_median': 1094.829833984375,
#   'mill_WBF_PIRO_1_TEMP_PIR2_ni_ALL_PTS_21_mean': 1095.1888916015625,
#   'WBF_sgl_1_PIECE_PK_ni_single': 2.4030712380000006e+19,
#   'WBF_sgl_1_FURNACE_FK_ni_single': 1.0,
#   'WBF_sgl_1_CHARGING_TIME_ni_single': None,
#   'WBF_sgl_1_TOT_X_NODE_ni_single': 100.0,
#   'WBF_sgl_1_TOT_Y_NODE_ni_single': 7.0,
#   'WBF_sgl_1_TOT_Z_NODE_ni_single': 7.0,
#   'WBF_sgl_1_X_POS_ni_single': 599.0,
#   'WBF_sgl_1_X_COORD_ni_single': 4540.5,
#   'WBF_sgl_1_IS_DISCHARGED_ni_single': None,
#   'WBF_sgl_1_DISCHARGING_TIME_ni_single': None,
#   'WBF_sgl_1_MARKA_ni_single': None,
#   'WBF_sgl_1_BISRA_ni_single': 5.0,
#   'WBF_sgl_1_STRATEGY_ni_single': 1.0,
#   'WBF_sgl_1_L_WBF_ni_single': 7883.0,
#   'WBF_sgl_1_H_WBF_ni_single': 300.0,
#   'WBF_sgl_1_W_WBF_ni_single': 366.0,
#   'WBF_sgl_1_WEIGHT_ni_single': 6789.0,
#   'WBF_sgl_1_CHG_TEMP_ni_single': 25.0,
#   'WBF_sgl_1_PLA_PACE_RATE_ni_single': 117.0,
#   'WBF_sgl_1_CUR_PACE_RATE_ni_single': 147.0,
#   'WBF_sgl_1_TARGET_TEMP_ni_single': 1220.0,
#   'WBF_sgl_1_TARGET_TEMP_Cor_ni_single': -57.0,
#   'WBF_sgl_1_DCHG_TARGET_TEMP_PDI_ni_single': 1220.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_CNV_ni_single': 108.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_PHE_ni_single': 705.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_HE1_ni_single': 1005.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_HE2_ni_single': 1181.0,
#   'WBF_sgl_1_CALC_MEAN_TEMP_SOA_ni_single': 1201.0,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_CNV_ni_single': 148.805755615234,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_PHE_ni_single': 779.681701660156,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_HE1_ni_single': 1055.44604492188,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_HE2_ni_single': 1185.98889160156,
#   'WBF_sgl_1_TARGET_MEAN_TEMP_SOA_ni_single': 1193.0,
#   'WBF_sgl_1_CROSSING_TIME_CNV_ni_single': None,
#   'WBF_sgl_1_CROSSING_TIME_PHE_ni_single': None,
#   'WBF_sgl_1_CROSSING_TIME_HE1_ni_single': None,
#   'WBF_sgl_1_CROSSING_TIME_HE2_ni_single': None,
#   'WBF_sgl_1_CROSSING_TIME_SOA_ni_single': None,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_HEAD_ni_single': 1209.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_HEAD_ni_single': 1194.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_HEAD_ni_single': 1189.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_CENTR_ni_single': 1215.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_CENTR_ni_single': 1205.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_CENTR_ni_single': 1204.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_TOP_TAIL_ni_single': 1207.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_CORE_TAIL_ni_single': 1194.0,
#   'WBF_sgl_1_CALC_DISCHARGING_TEMP_BOTTOM_TAIL_ni_single': 1187.0,
#   'WBF_sgl_1_VALIDITY_ni_single': None,
#   'WBF_sgl_1_C_MODE_PERC_ni_single': 100.0,
#   'WBF_sgl_1_O_C_MODE_PERC_ni_single': None,
#   'WBF_sgl_1_O_MODE_PERC_ni_single': None,
#   'WBF_sgl_1_OXI_DEPTH_ni_single': 0.585743004205563,
#   'WBF_sgl_1_DEC_DEPTH_ni_single': 2.22830173681448,
#   'WBF_sgl_1_DELAY_ni_single': 54.8511373,
#   'WBF_sgl_1_MAX_SKID_TEMP_ni_single': -60.0,
#   'WBF_sgl_1_X_POS_MAX_SKID_ni_single': 719.0,
#   'WBF_sgl_1_MAX_DELTA_TEMP_ni_single': 79.0000205252711,
#   'WBF_sgl_1_DELTA_T_CROSS_ni_single': 10.0,
#   'WBF_sgl_1_DELTA_T_TOP_SURFACE_ni_single': 12.9999024686874,
#   'WBF_sgl_1_CALC_T_DCHG_TOP_SURFACE_ni_single': 1217.82513050629,
#   'WBF_sgl_1_MIN_RES_TIME_ni_single': 10153.0,
#   'WBF_sgl_1_STEEL_CODE_ni_single': 569.0,
#   'WBF_sgl_1_STEEL_MARK_ni_single': None,
#   'WBF_sgl_1_ROLLING_PROFILE_ni_single': None,
#   'WBF_sgl_1_WEIGTH_IN_ni_single': 6690.0,
#   'WBF_sgl_1_WEIGHT_OUT_ni_single': 6690.0,
#   'WBF_sgl_1_TIME_IN_ni_single': None,
#   'WBF_sgl_1_TIME_OUT_ni_single': None,
#   'WBF_sgl_1_HEIGHT_IN_ni_single': None,
#   'WBF_sgl_1_HEIGHT_OUT_ni_single': None,
#   'WBF_sgl_1_LENGTH_IN_ni_single': 7883.0,
#   'WBF_sgl_1_LENGTH_OUT_ni_single': 7883.0,
#   'WBF_sgl_1_WIDTH_IN_ni_single': None,
#   'WBF_sgl_1_WIDTH_OUT_ni_single': None,
#   'WBF_sgl_1_LENGTH_ORDERED_ni_single': 7.93,
#   'WBF_sgl_1_DENSITY_ni_single': 852.0,
#   'WBF_sgl_1_TEMPERATURE_IN_ni_single': None,
#   'WBF_sgl_1_TEMPERATURE_OUT_ni_single': 1.0,
#   'WBF_sgl_1_TEMPERATURE_MAX_ni_single': 1187.0,
#   'WBF_sgl_1_TEMPERATURE_MIN_ni_single': 1186.0,
#   'WBF_sgl_1_TEMPERATURE_AVG_ni_single': 1187.0,
#   'WBF_sgl_1_WEIGHT_PROCESSED_ni_single': 6.7308,
#   'WBF_sgl_1_HEIGHT_PROCESSED_ni_single': 0.302,
#   'WBF_sgl_1_LENGTH_PROCESSED_ni_single': 7.9,
#   'WBF_sgl_1_WIDTH_PROCESSED_ni_single': 0.366,
#   'WBF_sgl_1_PZAG_ni_single': None,
#   'WBF_sgl_1_MELT_NUMBER_ni_single': None,
#   'WBF_sgl_1_WEIGHT_ORDERED_ni_single': 6.75636,
#   'WBF_sgl_1_MARKA_PROCESSED_ni_single': None,
#   'WBF_sgl_1_STRAND_BILLET_NUMBER_ni_single': 1.0,
#   'WBF_sgl_1_STRAND_NUMBER_ni_single': 1.0,
#   'WBF_sgl_1_CONTROL_ni_single': 1.0,
#   'WBF_sgl_1_STATUS_ni_single': 3.0,
#   'WBF_sgl_1_ATTESTATED_ni_single': None,
#   'WBF_sgl_1_PROFILE_VALID_ID_ni_single': 1981.0,
#   'WBF_sgl_1_Z1_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z2_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z3_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z4_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z5_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z6_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z7_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z8_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z9_LV2_IN_percent_ni_single': 100.0,
#   'WBF_sgl_1_Z10_LV2_IN_percent_ni_single': 100.0}}

# %%
dic =  {
"Л54321098_2023": {
    "LNK100": r"\\ZSMK-9684-001\Data\2023\07\07\ipsrnk\rail_points_files\20230707001909_25178X302_IPSRNK_1_L.csv",
    "U0": r"\\ZSMK-9684-001\Data\2023\08\09\U0\rollings_points_files\20230809113255_Л258973020_U0_1_L.csv"
},
"Л98765432_2023": {
    "WBF_PIRO": r"\\ZSMK-9684-001\Data\2023\12\14\wbf\billet_pirometer_files\20231214172621_23-Л211344030_WBF_1_T2.csv",
    "U0": r"\\ZSMK-9684-001\Data\2023\08\09\U0\rollings_points_files\20230809113255_Л258973020_U0_1_L.csv"
}
}

# %%
for source, filepath in dic["Л54321098_2023"].items():
    print(source + ":" + filepath)
# Out:
# LNK100:\\ZSMK-9684-001\Data\2023\07\07\ipsrnk\rail_points_files\20230707001909_25178X302_IPSRNK_1_L.csv
# U0:\\ZSMK-9684-001\Data\2023\08\09\U0\rollings_points_files\20230809113255_Л258973020_U0_1_L.csv
